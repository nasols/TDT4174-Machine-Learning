# %% [markdown]
# # Short notebook 1
# To reproduce submission 'catboost_prelag_17.csv' with Public score: 150.254739

# %%
# IMPORTS 

import numpy as np
import warnings
import matplotlib.pylab as plt
import pandas as pd
from catboost import CatBoostRegressor

# %% [markdown]
# # Import Data Manager

# %%
# DM CLASS
 
class Data_Manager() : 

    def __init__(self) : 
        # Y_train
        self.train_a = pd.DataFrame() 
        self.train_b = pd.DataFrame()
        self.train_c = pd.DataFrame()

        self.X_train_observed_a = pd.DataFrame()
        self.X_train_observed_b = pd.DataFrame()
        self.X_train_observed_c = pd.DataFrame()

        self.X_train_estimated_a = pd.DataFrame()
        self.X_train_estimated_b = pd.DataFrame()
        self.X_train_estimated_c = pd.DataFrame()

        self.X_test_estimated_a = pd.DataFrame()
        self.X_test_estimated_b = pd.DataFrame()
        self.X_test_estimated_c = pd.DataFrame()

        self.data_A = pd.DataFrame()    
        self.data_B = pd.DataFrame()
        self.data_C = pd.DataFrame()

        self.data = pd.DataFrame()
        self.X_test_estimated = pd.DataFrame()

        # X_train_obs, Y_train_obs
        self.data_A_obs = pd.DataFrame()    
        self.data_B_obs = pd.DataFrame()
        self.data_C_obs = pd.DataFrame()
        
        # X_train_obs, Y_train_obs
        self.data_A_es = pd.DataFrame()
        self.data_B_es = pd.DataFrame()
        self.data_C_es = pd.DataFrame()

        self.amplitude = np.zeros(3) # amp_a, amp_b, amp_c

    def data_loader(self): 
        """
        Function that loads the datasets into data manager, loads all data 
        """

        self.train_a = pd.read_parquet('A/train_targets.parquet')
        self.train_a = self.train_a.rename(columns={"time":"date_forecast"})

        self.train_b = pd.read_parquet('B/train_targets.parquet')
        self.train_b = self.train_b.rename(columns={"time":"date_forecast"})

        self.train_c = pd.read_parquet('C/train_targets.parquet')
        self.train_c = self.train_c.rename(columns={"time":"date_forecast"})

        self.X_train_estimated_a = pd.read_parquet('A/X_train_estimated.parquet')
        self.X_train_estimated_b = pd.read_parquet('B/X_train_estimated.parquet')
        self.X_train_estimated_c = pd.read_parquet('C/X_train_estimated.parquet')

        self.X_train_observed_a = pd.read_parquet('A/X_train_observed.parquet')
        self.X_train_observed_b = pd.read_parquet('B/X_train_observed.parquet')
        self.X_train_observed_c = pd.read_parquet('C/X_train_observed.parquet')

        self.X_test_estimated_a = pd.read_parquet('A/X_test_estimated.parquet')
        self.X_test_estimated_b = pd.read_parquet('B/X_test_estimated.parquet')
        self.X_test_estimated_c = pd.read_parquet('C/X_test_estimated.parquet')
    
    def dms2dm(self, dms):
        self.train_a = dms.data['train_a']
        self.train_b = dms.data['train_b']
        self.train_c = dms.data['train_c']

        self.X_train_estimated_a = dms.data['X_train_estimated_a']
        self.X_train_estimated_b = dms.data['X_train_estimated_b']
        self.X_train_estimated_c = dms.data['X_train_estimated_c']

        self.X_train_observed_a = dms.data['X_train_observed_a']
        self.X_train_observed_b = dms.data['X_train_observed_b']
        self.X_train_observed_c = dms.data['X_train_observed_c']

        self.X_test_estimated_a = dms.data['X_test_estimated_a']
        self.X_test_estimated_b = dms.data['X_test_estimated_b']
        self.X_test_estimated_c = dms.data['X_test_estimated_c']

        self.data_A_obs = dms.data['data_A_obs']
        self.data_B_obs = dms.data['data_B_obs']
        self.data_C_obs = dms.data['data_C_obs']

        self.data_A_es = dms.data['data_A_es']
        self.data_B_es = dms.data['data_B_es']
        self.data_C_es = dms.data['data_C_es']

        self.data_A = dms.data['data_A']   
        self.data_B = dms.data['data_B']
        self.data_C = dms.data['data_C']

        self.amplitude = dms.data['amplitude']

    def drop_feature(self, datasets:list[pd.DataFrame], features:list[str]):
        """
        Takes in list of datasets and removes features from the sets

        Returns list of altered datasets
        """

        altered_sets = []

        for set in datasets: 
            for feature in features:

                set = set.drop(feature, axis=1)

            altered_sets.append(set)

        return altered_sets
    
    def combine_data(self): 
        """
        Combines datasets A, B and C into one set containing all features and pv_measurements. 

        Combine_observed_estimated (bool) determines if you want one single set for A B C or keep the observed and estimated
        data split 

        Warning! Data should have no NaN values or be of same frequency before combining! 
        """
        weather_data_A = pd.concat([self.X_train_observed_a, self.X_train_estimated_a], axis=0, ignore_index=True)
        weather_data_B = pd.concat([self.X_train_observed_b, self.X_train_estimated_b], axis=0, ignore_index=True)
        weather_data_C = pd.concat([self.X_train_observed_c, self.X_train_estimated_c], axis=0, ignore_index=True)

        self.data_A = pd.merge(weather_data_A, self.train_a, how="left", on="date_forecast")
        self.data_B = pd.merge(weather_data_B, self.train_b,  on="date_forecast", how="left")
        self.data_C = pd.merge(weather_data_C, self.train_c, on="date_forecast", how="left")

        if ( self.data_A.columns.__contains__("date_calc") ): 
            self.data_A = self.data_A.drop("date_calc", axis=1)
            self.data_B = self.data_B.drop("date_calc", axis=1)
            self.data_C = self.data_C.drop("date_calc", axis=1)

        if (self.train_a.shape[0] > 35000 ) : 
            
            self.data_A = self.makima_interpolate(self.data_A).dropna()
            self.data_B = self.makima_interpolate(self.data_B).dropna()
            self.data_C = self.makima_interpolate(self.data_C).dropna()
        
        elif (self.train_a.shape[0] < 35000) : 
            self.data_A = self.data_A.dropna()
            self.data_B = self.data_B.dropna()
            self.data_C = self.data_C.dropna()

        if self.data_A.isna().sum().sum() > 0 :
            warnings.warn("Warning! Data should have no NaN values or be of same frequency before combining! Use impute or interpolation on data before combining! This could also come from dates in the combined datasets not overlapping fully.")

        return self.data_A, self.data_B, self.data_C

    def impute_data(self, datasets, advanced_imputer=False):

        """
        imputes data to fill in missing values

        takes in a list of datasets

        returns list of imputed data

        removes all columns consisting entirely of nan 
        """

        from sklearn.experimental import enable_iterative_imputer
        from sklearn.impute import IterativeImputer, SimpleImputer
        from tqdm import tqdm
        imputed_sets = []

        for set in tqdm(datasets): 

            # storing columns to lable after impute, also removing date column as this does not work with impute 
            cols = set.columns 

            if set.columns.__contains__("date_forecast"): 
                dates = set["date_forecast"]
            
            if set.columns.__contains__("date_calc"): 
                set = set.drop("date_calc", axis=1)

            cols = set.columns.delete(0)

            set_wo_date = set.drop("date_forecast", axis=1)

            #imputing (estimating) missing values 
            imp = SimpleImputer(missing_values=np.nan, strategy="mean", add_indicator=False)
            imp.fit(set_wo_date)
            set_wo_date = pd.DataFrame(imp.transform(set_wo_date), columns=imp.get_feature_names_out())
            

            # setting column lables basck
            set = set_wo_date
            
            set["date_forecast"] = dates

            #sorting columns 
            cols = cols.tolist()
            cols.insert(0, "date_forecast")

            #set = set.fillna(0.0)

            imputed_sets.append(set)

        return imputed_sets
    
    def iterative_imputer(self, datasets) :

        from sklearn.experimental import enable_iterative_imputer
        from sklearn.impute import IterativeImputer, SimpleImputer
        from tqdm import tqdm
        imputed_sets = []
        imp = IterativeImputer(random_state=0, missing_values=np.nan, add_indicator=False, imputation_order="ascending", skip_complete=True)

        for set in tqdm(datasets): 

            cols = set.columns 

            if set.columns.__contains__("date_forecast"): 
                dates = set["date_forecast"]
            
            if set.columns.__contains__("date_calc"): 
                set = set.drop("date_calc", axis=1)
            
            cols = set.columns.delete(0)

            set_wo_date = set.drop("date_forecast", axis=1)

            print("getting to imputing")
            #imputing (estimating) missing values 
            imp.fit(set_wo_date)
            
            set_wo_date = pd.DataFrame(imp.transform(set_wo_date), columns=imp.get_feature_names_out())

             # setting column lables basck
            set = set_wo_date
            
            set["date_forecast"] = dates

            # set = set.fillna(0.0)


            #sorting columns 
            cols = cols.tolist()
            cols.insert(0, "date_forecast")

            imputed_sets.append(set)

        return imputed_sets

    def resample_data(self, datasets, freq) : 


        """
        resamples the given dataset into the correct frequency. 
        H : hourly 
        15T : 15min 
        """

        corr = []

        for set in datasets: 
            set_hourly = set.resample(freq, on="date_forecast").mean()

            set_dates = set["date_forecast"].dt.date.unique().tolist()

            set_hourly["date_forecast"] = set_hourly.index

            set_corr = set_hourly[set_hourly["date_forecast"].dt.date.isin(set_dates)]

            set_corr.index = pd.RangeIndex(0, len(set_corr))
            corr.append(set_corr)

        
        return corr

    def add_feature(dataset, feature_name, data) :

        added_set = dataset[feature_name] = data

        return added_set
    
    def set_info(self, dataset:pd.DataFrame):

        (dataset.info())

    def plot_feature(self, dataset:pd.DataFrame, featureName:str):
        
        fig, axs = plt.subplots(1, 1, figsize=(20, 10))

        dataset[['date_forecast', featureName]].set_index("date_forecast").plot(ax=axs, title=featureName, color='red')
       
    def KNNImputing(self, datasets) :
        from sklearn.impute import KNNImputer
        from tqdm import tqdm

        imputed_sets = []

        for set in tqdm(datasets): 

            # storing columns to lable after impute, also removing date column as this does not work with impute 
            cols = set.columns 

            if set.columns.__contains__("date_forecast"): 
                dates = set["date_forecast"]
            
            if set.columns.__contains__("date_calc"): 
                set = set.drop("date_calc", axis=1)

            cols = set.columns.delete(0)

            set_wo_date = set.drop("date_forecast", axis=1)

            #imputing (estimating) missing values 
            imp = KNNImputer(n_neighbors=40, weights="distance", )
            imp.fit(set_wo_date)
            set_wo_date = pd.DataFrame(imp.transform(set_wo_date), columns=imp.get_feature_names_out())
            

            # setting column lables basck
            set = set_wo_date
            
            set["date_forecast"] = dates

            #sorting columns 
            cols = cols.tolist()
            cols.insert(0, "date_forecast")

            ## set = set.fillna(0.0)

            imputed_sets.append(set)

        return imputed_sets

    def makima_interpolate(self, data: pd.DataFrame) -> pd.DataFrame:

        from scipy.interpolate import Akima1DInterpolator
        # Extract non-missing values and their indices

        dates = data["date_forecast"]

        non_nan_indices = data['pv_measurement'].dropna().index
        non_nan_values = data['pv_measurement'].dropna().values

        # Apply the Modified Akima Interpolation
        akima = Akima1DInterpolator(non_nan_indices, non_nan_values)
        interpolated_values = akima(data.index)

        # Replace the original column with the interpolated values
        data['pv_measurement'] = interpolated_values

        data[data["pv_measurement"]< 0] = 0 ; 

        data["date_forecast"] = dates; 

        return data
    
    def normalize_data(self) : 
        from sklearn import preprocessing

        if (self.data_A.empty) : 
            print( "empty ")
            relevant_sets = [attr for attr in dir(self) if not callable(getattr(self, attr)) and not attr.startswith("__") and not attr.__contains__("data") and not attr == 'amplitude' and not attr.__contains__("normalizing")]

        else: 
            print("not emptu")
            relevant_sets = [attr for attr in dir(self) if not callable(getattr(self, attr)) and not attr.startswith("__") and attr.__contains__("data_") and not attr.__contains__("_es") and not attr.__contains__("obs") or attr.__contains__("_estimated_")]
        self.__setattr__("normalizing_consts", {})

        print(relevant_sets)

        min_max_scaler = preprocessing.MinMaxScaler()
        normalizer = preprocessing.Normalizer()
        

        for att in relevant_sets: 
            set : pd.DataFrame = self.__getattribute__(att)

            cols = set.columns 

            if set.columns.__contains__("date_forecast"): 
                dates = set["date_forecast"]
            
            if set.columns.__contains__("date_calc"): 
                set = set.drop("date_calc", axis=1)

            cols = set.columns.delete(0)

            set_wo_date = set.drop("date_forecast", axis=1)

            x = set_wo_date.values

            x_normalized = min_max_scaler.fit_transform(x)

            self.normalizing_consts[att] = (set_wo_date.min(), np.abs(set_wo_date.max() - set_wo_date.min())) ## storing normalizing consts for later 
            
            normalized_set = pd.DataFrame(x_normalized)

            normalized_set.columns = cols

            

            self.__setattr__(att, normalized_set)
        
    def scaling(self, preds, location:str) : 

        """
        FORMAT OF PREDICTIONS SHOULD BE 1 COLUMN WITH PREDS

        LOCATION: A B or C
        """

        relevant_sets = [attr for attr in dir(self) if not callable(getattr(self, attr)) and not attr.startswith("__") and not attr.__contains__("data") and not attr == 'amplitude' and (attr.__contains__("train_a") or attr.__contains__("train_b") or attr.__contains__("train_c"))]
        if (self.data_A.empty) : 
            print( "empty ")
            relevant_sets = [attr for attr in dir(self) if not callable(getattr(self, attr)) and not attr.startswith("__") and not attr.__contains__("data") and not attr == 'amplitude' and not attr.__contains__("normalizing")]

        else: 
            print("not emptu")
            relevant_sets = [attr for attr in dir(self) if not callable(getattr(self, attr)) and not attr.startswith("__") and attr.__contains__("data_") and not attr.__contains__("es") and not attr.__contains__("obs")]

        
        loc_index = 0

        if location.capitalize() == "A" :

            loc_index = 0

        elif location.capitalize() == "B": 
        
            loc_index = 1

        elif location.capitalize() == "C": 

            loc_index = 2
           
        elif ( location.capitalize() == "D"): 

            A = pd.DataFrame(preds[0:720])
            B = pd.DataFrame(preds[720:2*720])
            C = pd.DataFrame(preds[2*720:])

            min = self.normalizing_consts["data_A"][0][0]
            diff = self.normalizing_consts["data_A"][1][0]

            scaled_A = (A+min) * diff



            min = self.normalizing_consts["data_B"][0][0]
            diff = self.normalizing_consts["data_B"][1][0]

            scaled_B = (B+min) * diff



            min = self.normalizing_consts["data_C"][0][0]
            diff = self.normalizing_consts["data_C"][1][0]

            scaled_C = (C+min) * diff


            print(A.shape)
            scaled_set = pd.concat([scaled_A, scaled_B, scaled_C])

            return scaled_set

        relevant_set = relevant_sets[loc_index]

    
        min = self.normalizing_consts[relevant_set][0][0]
        diff = self.normalizing_consts[relevant_set][1][0]

        scaled_set = (preds + min) * diff

        return scaled_set
    
    def combine_overlap_BC(self): 
        import math
        """
        This function is created for merging B and C to remove the nan values apparent when merging pv_measurement to the weather data
        This is because of the observation that B and C overlap and where one is missing the other fills in. 
        Must run combine data first to create data_A B C
        """

        original_B = self.data_B
        original_C = self.data_C  

        b2c_scaling = original_B["pv_measurement"].max()/original_C["pv_measurement"].max()

        print(b2c_scaling)      

        original_C[original_C.isnull()] = self.data_B
        original_B[original_B.isnull()] = self.data_C

        self.data_C = original_C.dropna()
        self.data_B = original_B.dropna()

    def sorting_columns_inMainSets(self):

        A = self.data_A 
        cols = A.columns.tolist()

        #sorting columns 
        cols.remove("date_forecast")
        cols.remove("pv_measurement")
        cols.insert(0, "pv_measurement")
        cols.insert(0, "date_forecast")

        A = A[cols]
        self.data_A = A

        #------------------------------------------------------------# 

        B = self.data_B
        cols = B.columns.tolist()

        #sorting columns 
        cols.remove("date_forecast")
        cols.remove("pv_measurement")
        cols.insert(0, "pv_measurement")
        cols.insert(0, "date_forecast")

        B = B[cols]
        self.data_B = B 

        #------------------------------------------------------------#

        C = self.data_C

        cols = C.columns.tolist()

        #sorting columns 
        cols.remove("date_forecast")
        cols.remove("pv_measurement")
        cols.insert(0, "pv_measurement")
        cols.insert(0, "date_forecast")

        C = C[cols]
        self.data_C = C

        #------------------------------------------------------------#

        A = self.X_test_estimated_a

        cols = A.columns.tolist()

        #sorting columns 
        cols.remove("date_forecast")
        cols.insert(0, "date_forecast")

        A = A[cols]
        self.X_test_estimated_a = A

        #------------------------------------------------------------#

        B = self.X_test_estimated_b

        cols = B.columns.tolist()

        #sorting columns 
        cols.remove("date_forecast")
        cols.insert(0, "date_forecast")

        B = B[cols]
        self.X_test_estimated_b = B

        #------------------------------------------------------------#

        C = self.X_test_estimated_c

        cols = C.columns.tolist()

        #sorting columns 
        cols.remove("date_forecast")
        cols.insert(0, "date_forecast")

        C = C[cols]
        self.X_test_estimated_c = C

        #------------------------------------------------------------#

        if ( not self.data.empty) : 
            data = self.data

            cols = data.columns.tolist()

            #sorting columns 
            cols.remove("date_forecast")
            cols.insert(0, "date_forecast")

            data = data[cols]
            self.data = data

    def remove_constant_periods(self, period_length, ignore_values=[]) :
        train_a = self.data_A.reset_index(drop=True)
        train_b = self.data_B.reset_index(drop=True)
        train_c = self.data_C.reset_index(drop=True)

        y_train_a_const_idx, ca = find_const_interval(train_a, 'pv_measurement', period_length, ignore_values)
        print('y_train_a anomalies:',ca)

        y_train_b_const_idx, cb = find_const_interval(train_b, 'pv_measurement', period_length, ignore_values)
        print('y_train_b anomalies:',cb)

        y_train_c_const_idx, cc = find_const_interval(train_c, 'pv_measurement', period_length, ignore_values)
        print('y_train_c anomalies:',cc)


        date_forecast_a_const = train_a.iloc[y_train_a_const_idx]['date_forecast']
        date_forecast_a_const_values = date_forecast_a_const.values
        train_a = train_a[~train_a['date_forecast'].isin(date_forecast_a_const_values)]

        date_forecast_b_const = train_b.iloc[y_train_b_const_idx]['date_forecast']
        date_forecast_b_const_values = date_forecast_b_const.values
        train_b = train_b[~train_b['date_forecast'].isin(date_forecast_b_const_values)]

        date_forecast_c_const = train_c.iloc[y_train_c_const_idx]['date_forecast']
        date_forecast_c_const_values = date_forecast_c_const.values
        train_c = train_c[~train_c['date_forecast'].isin(date_forecast_c_const_values)]

        self.data_A = train_a
        self.data_B = train_b
        self.data_C = train_c
                
    def split_timeseries(self, X, y, num_splits):

        num_rows = X.shape[0]

        split_length = num_rows // num_splits

        all_splits = []

        end_idx = split_length

        all_splits.append([np.arange(0, round(split_length*0.9), 1), np.arange(round(split_length*0.9), split_length, 1)])


        while 2*end_idx < num_rows: 

            all_splits.append([np.arange(round(end_idx), end_idx + round(0.9*end_idx), 1), np.arange(round(end_idx*0.9)+end_idx, 2*end_idx, 1)])

            end_idx += split_length

        print(end_idx + split_length)
        rest = num_rows - end_idx 

        all_splits.append([np.arange(round(2), )])

        print(all_splits) 

    def add_location(self, dataset:pd.DataFrame, location):

        if location == "A": loc = 0 
        if location == "B": loc = 1 
        if location == "C": loc = 2

        index = dataset.index

        loc_column = pd.DataFrame()
        loc_column.index = index
        loc_column["location"] = loc

        dataset["location"] = loc

        return dataset
    
    def add_lag_feature(self, target_attribute, lag):

        lag_attribute = target_attribute + "_lag_" + str(lag)

        self.data_A[lag_attribute] = self.data_A[target_attribute].shift(lag).fillna(0)
        self.data_B[lag_attribute] = self.data_B[target_attribute].shift(lag).fillna(0)
        self.data_C[lag_attribute] = self.data_C[target_attribute].shift(lag).fillna(0)

        self.X_test_estimated_a[lag_attribute] = self.X_test_estimated_a[target_attribute].shift(lag).fillna(0)
        self.X_test_estimated_b[lag_attribute] = self.X_test_estimated_b[target_attribute].shift(lag).fillna(0)
        self.X_test_estimated_c[lag_attribute] = self.X_test_estimated_c[target_attribute].shift(lag).fillna(0)

        

    def combine_all_data(self): 

        relevant_sets_A = [attr for attr in dir(self) if attr.__eq__("data_A") or attr.__eq__("X_test_estimated_a")]
        relevant_sets_B = [attr for attr in dir(self) if attr.__eq__("data_B") or attr.__eq__("X_test_estimated_b")]
        relevant_sets_C = [attr for attr in dir(self) if attr.__eq__("data_C") or attr.__eq__("X_test_estimated_c")]

        print(relevant_sets_A)
        print(relevant_sets_B)
        print(relevant_sets_C)


        for set in relevant_sets_A : 
            self.__setattr__(set, self.add_location(self.__getattribute__(set), "A"))
        for set in relevant_sets_B : 
            self.__setattr__(set, self.add_location(self.__getattribute__(set), "B"))
        for set in relevant_sets_C : 
            self.__setattr__(set, self.add_location(self.__getattribute__(set), "C"))


        self.data = pd.concat([self.data_A, self.data_B, self.data_C], ignore_index=True)
        self.X_test_estimated = pd.concat([self.X_test_estimated_a, self.X_test_estimated_b, self.X_test_estimated_c], ignore_index=True)

    def remove_outliers_z_score(self, data:pd.DataFrame, threshold=3) : 
        
        from scipy import stats

        before = self.data["diffuse_rad:W"][0:3*720]

        dates = None 

        if "date_forecast" in data.columns: 

            dates = data["date_forecast"]
            data = data.drop("date_forecast", axis=1)

        z_scores = stats.zscore(data.astype(float))

        outliers = data[z_scores > threshold]
        outliers = outliers.notna()

        indexx = None

        if (len(outliers) > 1): 

            for outlier in outliers: 
                if (outlier != "index"):

                    index = data[outlier].loc[outliers[outlier] == True]

                    data[outlier] = data[outlier].replace(index.index, np.nan)


                    indexx = index
            

            data["date_forecast"] = dates

            data = self.KNNImputing([data])[0]
            data = data.reset_index(drop=True)
            self.sorting_columns_inMainSets()
            print(self.set_info(self.data))
            
            x = np.arange(0, 3*720, 1)
            fig, axs = plt.subplots(1, 1, figsize=(20, 10))
            plt.plot(x, before, c="blue", label="before")            
            plt.plot(x, data["diffuse_rad:W"][0:3*720], c="orange", label="after") 
            plt.legend()           
            plt.show()
            return data

        else: 
            print("no outliers")
            return data

# %% [markdown]
# # Import Helper functions

# %%
# HELPERS

def impute (datasets: list[pd.DataFrame]) : 

    from sklearn.experimental import enable_iterative_imputer
    from sklearn.impute import IterativeImputer, SimpleImputer
    import numpy as np
    import pandas as pd
    

    imputed_sets = []

    for set in datasets: 

        # storing columns to lable after impute, also removing date column as this does not work with impute 
        cols = set.columns 

        if set.columns.__contains__("date_forecast"): 
            dates = set["date_forecast"]
        
        if set.columns.__contains__("date_calc"): 
            set = set.drop("date_calc", axis=1)

        cols = set.columns.delete(0)

        set_wo_date = set.drop("date_forecast", axis=1)

        #imputing (estimating) missing values 
        imp = SimpleImputer(missing_values=np.nan, strategy="mean", add_indicator=False)
        imp.fit(set_wo_date)
        set_wo_date = imp.transform(set_wo_date)
        set_wo_date = pd.DataFrame(set_wo_date)

        # setting column lables basck
        set = set_wo_date
        set.columns = set.columns.astype(str)
        set.columns = cols
        set["date_forecast"] = dates

        #sorting columns 
        cols = cols.tolist()
        cols.insert(0, "date_forecast")

        set = set[cols]

        set = set.fillna(0.0)

        imputed_sets.append(set)

    return imputed_sets

def drop_feature(datasets:list[pd.DataFrame], features:list[str]):

    altered_sets = []

    for set in datasets: 
        for feature in features:

            set = set.drop(feature, axis=1)

        altered_sets.append(set)

    return altered_sets

def find_const_interval(df, target_attribute, interval_length, ignore_values=[]):
    """
    Find all the intervals of the given length in the dataset where the target_attribute is constant.

    Parameters:
    df (pandas.DataFrame): The input dataframe.
    target_attribute (str): The target attribute to check for constant values.
    interval_length (int): The length of the interval to search for.

    Returns:
    list: A list of indexes of all the values in the intervals where the target_attribute is constant for the given interval length or bigger.
    """
    idxs = []
    intervals_found = 0
    i = 0
    while i + interval_length < len(df) - 1:
        if df[target_attribute][i:i+interval_length].nunique() == 1 and df[target_attribute][i] not in ignore_values:
            j = i + interval_length - 1
            value = df[target_attribute][i]
            while value == df[target_attribute][j] and j < len(df) - 1:
                j += 1
            idxs.extend(list(range(i, j)))
            i = j+2
            intervals_found += 1
        else:
            i += 1
    return idxs, intervals_found

def donate_missing_rows(reciever, donor, target_attribute = 'date_forecast', scalepv = False):
    """
    Add rows from donor to reciever where the target_attribute is missing in reciever.

    Parameters:
    reciever (pandas.DataFrame): The dataframe to add rows to.
    donor (pandas.DataFrame): The dataframe to add rows from.
    target_attribute (str): The target attribute to check for missing values.

    Returns:
    tuple: A tuple containing the updated reciever dataframe and the number of rows that were donated.
    """
    donor_copy = donor.copy()
    if scalepv:
        scale = reciever['pv_measurement'].mean() / donor['pv_measurement'].mean()
        donor_copy['pv_measurement'] = donor_copy['pv_measurement'] * scale

    donated_rows = 0
    for date in donor_copy[target_attribute]:
        if date not in reciever[target_attribute].values:
            new_row = donor_copy[donor_copy[target_attribute] == date]
            reciever = pd.concat([reciever, new_row], ignore_index=True)
            donated_rows += 1
    reciever = reciever.sort_values(target_attribute).reset_index(drop=True)

    return reciever, donated_rows

# %% [markdown]
# ## Import Data

# %%
# IMPORT DATA

# instanciate a new datamanager 
dm = Data_Manager()
# loads all data into the datamanager 
dm.data_loader()

# %% [markdown]
# # Data Preparation

# %%
# REMOVING FEATURES WITH NULL VALUES

dm.X_train_observed_a = dm.X_train_observed_a.drop("snow_density:kgm3", axis=1)
dm.X_train_observed_b = dm.X_train_observed_b.drop("snow_density:kgm3", axis=1) 
dm.X_train_observed_c = dm.X_train_observed_c.drop("snow_density:kgm3", axis=1) 

dm.X_train_estimated_a = dm.X_train_estimated_a.drop("snow_density:kgm3", axis=1)
dm.X_train_estimated_b = dm.X_train_estimated_b.drop("snow_density:kgm3", axis=1)
dm.X_train_estimated_c = dm.X_train_estimated_c.drop("snow_density:kgm3", axis=1)

dm.X_train_observed_a = dm.X_train_observed_a.drop("ceiling_height_agl:m", axis=1)
dm.X_train_observed_b = dm.X_train_observed_b.drop("ceiling_height_agl:m", axis=1) 
dm.X_train_observed_c = dm.X_train_observed_c.drop("ceiling_height_agl:m", axis=1) 
dm.X_train_estimated_a = dm.X_train_estimated_a.drop("ceiling_height_agl:m", axis=1)
dm.X_train_estimated_b = dm.X_train_estimated_b.drop("ceiling_height_agl:m", axis=1)
dm.X_train_estimated_c = dm.X_train_estimated_c.drop("ceiling_height_agl:m", axis=1)

dm.X_train_observed_a = dm.X_train_observed_a.drop("cloud_base_agl:m", axis=1)
dm.X_train_observed_b = dm.X_train_observed_b.drop("cloud_base_agl:m", axis=1) 
dm.X_train_observed_c = dm.X_train_observed_c.drop("cloud_base_agl:m", axis=1) 
dm.X_train_estimated_a = dm.X_train_estimated_a.drop("cloud_base_agl:m", axis=1)
dm.X_train_estimated_b = dm.X_train_estimated_b.drop("cloud_base_agl:m", axis=1)
dm.X_train_estimated_c = dm.X_train_estimated_c.drop("cloud_base_agl:m", axis=1)

dm.X_test_estimated_a = dm.X_test_estimated_a.drop("cloud_base_agl:m", axis=1)
dm.X_test_estimated_b = dm.X_test_estimated_b.drop("cloud_base_agl:m", axis=1) 
dm.X_test_estimated_c = dm.X_test_estimated_c.drop("cloud_base_agl:m", axis=1) 

dm.X_test_estimated_a = dm.X_test_estimated_a.drop("ceiling_height_agl:m", axis=1)
dm.X_test_estimated_b = dm.X_test_estimated_b.drop("ceiling_height_agl:m", axis=1)
dm.X_test_estimated_c = dm.X_test_estimated_c.drop("ceiling_height_agl:m", axis=1)

dm.X_test_estimated_a = dm.X_test_estimated_a.drop("snow_density:kgm3", axis=1)
dm.X_test_estimated_b = dm.X_test_estimated_b.drop("snow_density:kgm3", axis=1)
dm.X_test_estimated_c = dm.X_test_estimated_c.drop("snow_density:kgm3", axis=1)

# %%
# DOWNSAMPLING DATA TO HOURLY

resamples = dm.resample_data([dm.X_train_observed_a, 
                                   dm.X_train_observed_b, 
                                   dm.X_train_observed_c, 
                                   dm.X_train_estimated_a,
                                   dm.X_train_estimated_b,
                                   dm.X_train_estimated_c,
                                   dm.X_test_estimated_a,
                                   dm.X_test_estimated_b,
                                   dm.X_test_estimated_c], "H")

dm.X_train_observed_a = resamples[0]
dm.X_train_observed_b = resamples[1] 
dm.X_train_observed_c = resamples[2] 
dm.X_train_estimated_a = resamples[3]
dm.X_train_estimated_b = resamples[4]
dm.X_train_estimated_c = resamples[5]
dm.X_test_estimated_a = resamples[6]
dm.X_test_estimated_b = resamples[7]
dm.X_test_estimated_c = resamples[8]

# %%
# COMBINING DATA

dm.data_A, dm.data_B, dm.data_C = dm.combine_data()
dm.sorting_columns_inMainSets()

print(dm.data_A.shape, dm.data_B.shape, dm.data_C.shape, dm.data.shape)

dates_A = dm.data_A["date_forecast"]
dates_B = dm.data_B["date_forecast"]
dates_C = dm.data_C["date_forecast"]
# Out:
# (34061, 44) (32819, 44) (26071, 44) (0, 0)

# %%
# ADDING LAG FEATURE

dm.add_lag_feature('direct_rad:W', -23)
# Out:
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\1131598103.py:677: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.X_test_estimated_a[lag_attribute] = self.X_test_estimated_a[target_attribute].shift(lag).fillna(0)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\1131598103.py:678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.X_test_estimated_b[lag_attribute] = self.X_test_estimated_b[target_attribute].shift(lag).fillna(0)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\1131598103.py:679: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.X_test_estimated_c[lag_attribute] = self.X_test_estimated_c[target_attribute].shift(lag).fillna(0)

# %%
# REMOVING CONSTANT Y PERIODS

dm.remove_constant_periods(12)
dm.remove_constant_periods(3, [0])
# Out:
# y_train_a anomalies: 673
# y_train_b anomalies: 651
# y_train_c anomalies: 511
# y_train_a anomalies: 0
# y_train_b anomalies: 15
# y_train_c anomalies: 58

# %%
# BC DONATION

updated_b, count_b = donate_missing_rows(dm.data_B, dm.data_C)
print('donated rows from C to B: ', count_b)
updated_c, count_c = donate_missing_rows(dm.data_C, dm.data_B)
print('donated rows from B to C: ', count_c)
# set donated data
dm.data_B = updated_b
dm.data_C = updated_c
# Out:
# donated rows from C to B:  3213
# donated rows from B to C:  6022

# %% [markdown]
# # Feature Engineering

# %%
# MAKING MONTHS ITS OWN FEATURE

def month_func(x): 
    return -6* np.cos(2*np.pi/12 * x) + 6


dm.data_A["month"] = month_func((dm.data_A["date_forecast"]).dt.month)
dm.data_B["month"] = month_func((dm.data_B["date_forecast"]).dt.month)
dm.data_C["month"] = month_func((dm.data_C["date_forecast"]).dt.month)

dm.X_test_estimated_a["month"] = month_func((dm.X_test_estimated_a["date_forecast"]).dt.month)
dm.X_test_estimated_b["month"] = month_func((dm.X_test_estimated_b["date_forecast"]).dt.month)
dm.X_test_estimated_c["month"] = month_func((dm.X_test_estimated_c["date_forecast"]).dt.month)
# Out:
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\4017892323.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_a["month"] = month_func((dm.X_test_estimated_a["date_forecast"]).dt.month)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\4017892323.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_b["month"] = month_func((dm.X_test_estimated_b["date_forecast"]).dt.month)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\4017892323.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_c["month"] = month_func((dm.X_test_estimated_c["date_forecast"]).dt.month)

# %%
# MAKING HOUR ITS OWN FEATURE

def hour_func(x): 
    return -12*np.cos(2*np.pi/24 * x) + 12

dm.X_test_estimated_a["hours"] = hour_func(dm.X_test_estimated_a["date_forecast"].dt.hour)
dm.X_test_estimated_b["hours"] = hour_func(dm.X_test_estimated_b["date_forecast"].dt.hour)
dm.X_test_estimated_c["hours"] = hour_func(dm.X_test_estimated_c["date_forecast"].dt.hour)

dm.data_A["hours"] =  hour_func(dm.data_A["date_forecast"].dt.hour)
dm.data_B["hours"] = hour_func(dm.data_B["date_forecast"].dt.hour)
dm.data_C["hours"] = hour_func(dm.data_C["date_forecast"].dt.hour)
# Out:
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\443554528.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_a["hours"] = hour_func(dm.X_test_estimated_a["date_forecast"].dt.hour)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\443554528.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_b["hours"] = hour_func(dm.X_test_estimated_b["date_forecast"].dt.hour)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\443554528.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_c["hours"] = hour_func(dm.X_test_estimated_c["date_forecast"].dt.hour)

# %%
# MAKING WEEK ITS OWN FEATURE

def week_func(x): 
    return -26*np.cos(2*np.pi/52 * x) + 26

dm.X_test_estimated_a["week_number"] = week_func(dm.X_test_estimated_a["date_forecast"].dt.isocalendar().week)
dm.X_test_estimated_b["week_number"] = week_func(dm.X_test_estimated_b["date_forecast"].dt.isocalendar().week)
dm.X_test_estimated_c["week_number"] = week_func(dm.X_test_estimated_c["date_forecast"].dt.isocalendar().week)

dm.data_A["week_number"] =  week_func(dm.data_A["date_forecast"].dt.isocalendar().week)
dm.data_B["week_number"] = week_func(dm.data_B["date_forecast"].dt.isocalendar().week)
dm.data_C["week_number"] = week_func(dm.data_C["date_forecast"].dt.isocalendar().week)
# Out:
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\2404366635.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_a["week_number"] = week_func(dm.X_test_estimated_a["date_forecast"].dt.isocalendar().week)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\2404366635.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_b["week_number"] = week_func(dm.X_test_estimated_b["date_forecast"].dt.isocalendar().week)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\2404366635.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_c["week_number"] = week_func(dm.X_test_estimated_c["date_forecast"].dt.isocalendar().week)

# %%
# MAKING DAY ITS OWN FEATURE

def day_func(x): 
    return -182.5*np.cos(2*np.pi/365 * x) + 182.5

dm.X_test_estimated_a["day_year"] = day_func(dm.X_test_estimated_a["date_forecast"].dt.dayofyear)
dm.X_test_estimated_b["day_year"] = day_func(dm.X_test_estimated_b["date_forecast"].dt.dayofyear)
dm.X_test_estimated_c["day_year"] = day_func(dm.X_test_estimated_c["date_forecast"].dt.dayofyear)

dm.data_A["day_year"] =  day_func(dm.data_A["date_forecast"].dt.dayofyear)
dm.data_B["day_year"] = day_func(dm.data_B["date_forecast"].dt.dayofyear)
dm.data_C["day_year"] = day_func(dm.data_C["date_forecast"].dt.dayofyear)
# Out:
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\3573495456.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_a["day_year"] = day_func(dm.X_test_estimated_a["date_forecast"].dt.dayofyear)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\3573495456.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_b["day_year"] = day_func(dm.X_test_estimated_b["date_forecast"].dt.dayofyear)
# C:\Users\loghe\AppData\Local\Temp\ipykernel_4808\3573495456.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dm.X_test_estimated_c["day_year"] = day_func(dm.X_test_estimated_c["date_forecast"].dt.dayofyear)

# %% [markdown]
# # Model

# %%
# DEFINING DATA

X_A_train = dm.data_A.iloc[:, 2:]
Y_A_train = dm.data_A.iloc[:, 1]

X_B_train = dm.data_B.iloc[:, 2:]
Y_B_train = dm.data_B.iloc[:, 1]

X_C_train = dm.data_C.iloc[:, 2:]
Y_C_train = dm.data_C.iloc[:, 1]

X_A_test = dm.X_test_estimated_a[dm.X_test_estimated_a.columns.intersection(X_A_train.columns)]
X_B_test = dm.X_test_estimated_b[dm.X_test_estimated_a.columns.intersection(X_A_train.columns)]
X_C_test = dm.X_test_estimated_c[dm.X_test_estimated_a.columns.intersection(X_A_train.columns)]

# %%
# MODELS

catModel_a = CatBoostRegressor()
catModel_b = CatBoostRegressor()
catModel_c = CatBoostRegressor()

# %%
# FITTING 

catModel_a.fit(X_A_train,Y_A_train)
catModel_b.fit(X_B_train,Y_B_train)
catModel_c.fit(X_C_train,Y_C_train)
# Out:
# Learning rate set to 0.067297
# 0:	learn: 1247.6744460	total: 17.9ms	remaining: 17.9s
# 1:	learn: 1186.0260545	total: 34.4ms	remaining: 17.1s
# 2:	learn: 1130.6434933	total: 47.8ms	remaining: 15.9s
# 3:	learn: 1078.1808484	total: 62.7ms	remaining: 15.6s
# 4:	learn: 1029.7823566	total: 77.6ms	remaining: 15.4s
# 5:	learn: 985.1533261	total: 93.6ms	remaining: 15.5s
# 6:	learn: 943.6513425	total: 109ms	remaining: 15.5s
# 7:	learn: 906.2632481	total: 124ms	remaining: 15.3s
# 8:	learn: 872.3898611	total: 136ms	remaining: 15s
# 9:	learn: 840.7465563	total: 151ms	remaining: 15s
# 10:	learn: 812.1274775	total: 166ms	remaining: 14.9s
# 11:	learn: 784.7392676	total: 177ms	remaining: 14.6s
# 12:	learn: 760.7637750	total: 192ms	remaining: 14.5s
# 13:	learn: 738.6033910	total: 204ms	remaining: 14.4s
# 14:	learn: 718.7709395	total: 217ms	remaining: 14.2s
# 15:	learn: 700.9002452	total: 229ms	remaining: 14.1s
# 16:	learn: 684.6465070	total: 244ms	remaining: 14.1s
# 17:	learn: 669.7781852	total: 258ms	remaining: 14.1s
# 18:	learn: 655.3989838	total: 271ms	remaining: 14s
# 19:	learn: 643.4918877	total: 283ms	remaining: 13.9s
# 20:	learn: 632.6491832	total: 297ms	remaining: 13.8s
# 21:	learn: 622.5557189	total: 309ms	remaining: 13.7s
# 22:	learn: 613.3884006	total: 322ms	remaining: 13.7s
# 23:	learn: 604.8894793	total: 334ms	remaining: 13.6s
# 24:	learn: 597.2057731	total: 349ms	remaining: 13.6s
# 25:	learn: 590.1973044	total: 360ms	remaining: 13.5s
# 26:	learn: 583.8130695	total: 373ms	remaining: 13.4s
# 27:	learn: 577.6729699	total: 386ms	remaining: 13.4s
# 28:	learn: 572.5951079	total: 402ms	remaining: 13.5s
# 29:	learn: 568.2300150	total: 417ms	remaining: 13.5s
# 30:	learn: 563.6772687	total: 429ms	remaining: 13.4s
# 31:	learn: 559.8357960	total: 442ms	remaining: 13.4s
# 32:	learn: 556.5615631	total: 455ms	remaining: 13.3s
# 33:	learn: 553.8157807	total: 468ms	remaining: 13.3s
# 34:	learn: 550.6430291	total: 483ms	remaining: 13.3s
# 35:	learn: 547.9593260	total: 495ms	remaining: 13.3s
# 36:	learn: 545.2304818	total: 507ms	remaining: 13.2s
# 37:	learn: 542.8672321	total: 521ms	remaining: 13.2s
# 38:	learn: 540.7946236	total: 534ms	remaining: 13.2s
# 39:	learn: 538.6122748	total: 551ms	remaining: 13.2s
# 40:	learn: 536.6202912	total: 566ms	remaining: 13.2s
# 41:	learn: 534.7471310	total: 577ms	remaining: 13.2s
# 42:	learn: 533.0692296	total: 590ms	remaining: 13.1s
# 43:	learn: 531.4137261	total: 604ms	remaining: 13.1s
# 44:	learn: 529.7492965	total: 617ms	remaining: 13.1s
# 45:	learn: 528.2863071	total: 631ms	remaining: 13.1s
# 46:	learn: 527.2282606	total: 644ms	remaining: 13.1s
# 47:	learn: 525.9550043	total: 659ms	remaining: 13.1s
# 48:	learn: 524.6123075	total: 672ms	remaining: 13.1s
# 49:	learn: 523.5972667	total: 690ms	remaining: 13.1s
# 50:	learn: 522.6058557	total: 707ms	remaining: 13.2s
# 51:	learn: 521.5594386	total: 719ms	remaining: 13.1s
# 52:	learn: 520.5891050	total: 734ms	remaining: 13.1s
# 53:	learn: 519.5216958	total: 751ms	remaining: 13.2s
# 54:	learn: 518.5143298	total: 765ms	remaining: 13.1s
# 55:	learn: 517.7196616	total: 779ms	remaining: 13.1s
# 56:	learn: 516.8073466	total: 793ms	remaining: 13.1s
# 57:	learn: 515.8707111	total: 805ms	remaining: 13.1s
# 58:	learn: 515.0379687	total: 819ms	remaining: 13.1s
# 59:	learn: 514.4332360	total: 831ms	remaining: 13s
# 60:	learn: 513.8008301	total: 845ms	remaining: 13s
# 61:	learn: 513.2569377	total: 858ms	remaining: 13s
# 62:	learn: 512.7710655	total: 871ms	remaining: 12.9s
# 63:	learn: 512.1000963	total: 882ms	remaining: 12.9s
# 64:	learn: 511.3946177	total: 895ms	remaining: 12.9s
# 65:	learn: 510.6906547	total: 908ms	remaining: 12.9s
# 66:	learn: 510.1523286	total: 923ms	remaining: 12.8s
# 67:	learn: 509.5122441	total: 935ms	remaining: 12.8s
# 68:	learn: 508.9790617	total: 947ms	remaining: 12.8s
# 69:	learn: 508.4616855	total: 958ms	remaining: 12.7s
# 70:	learn: 507.9235748	total: 969ms	remaining: 12.7s
# 71:	learn: 507.3927821	total: 982ms	remaining: 12.7s
# 72:	learn: 506.7999297	total: 993ms	remaining: 12.6s
# 73:	learn: 506.3668921	total: 1s	remaining: 12.6s
# 74:	learn: 505.8944635	total: 1.01s	remaining: 12.5s
# 75:	learn: 505.5321184	total: 1.02s	remaining: 12.5s
# 76:	learn: 505.1389113	total: 1.03s	remaining: 12.4s
# 77:	learn: 504.6040386	total: 1.05s	remaining: 12.4s
# 78:	learn: 504.3116273	total: 1.06s	remaining: 12.3s
# 79:	learn: 504.0155234	total: 1.07s	remaining: 12.3s
# 80:	learn: 503.6945674	total: 1.08s	remaining: 12.3s
# 81:	learn: 503.2243305	total: 1.09s	remaining: 12.2s
# 82:	learn: 502.7401431	total: 1.1s	remaining: 12.2s
# 83:	learn: 502.0415203	total: 1.11s	remaining: 12.2s
# 84:	learn: 501.5113598	total: 1.13s	remaining: 12.1s
# 85:	learn: 501.0798399	total: 1.14s	remaining: 12.1s
# 86:	learn: 500.7192613	total: 1.15s	remaining: 12.1s
# 87:	learn: 500.2373145	total: 1.16s	remaining: 12s
# 88:	learn: 499.8466744	total: 1.17s	remaining: 12s
# 89:	learn: 499.1939421	total: 1.18s	remaining: 12s
# 90:	learn: 498.6641560	total: 1.19s	remaining: 11.9s
# 91:	learn: 498.3434117	total: 1.2s	remaining: 11.9s
# 92:	learn: 497.7481971	total: 1.21s	remaining: 11.8s
# 93:	learn: 497.4321155	total: 1.22s	remaining: 11.8s
# 94:	learn: 497.0505086	total: 1.23s	remaining: 11.8s
# 95:	learn: 496.7569091	total: 1.24s	remaining: 11.7s
# 96:	learn: 496.4050299	total: 1.25s	remaining: 11.7s
# 97:	learn: 496.0678016	total: 1.26s	remaining: 11.6s
# 98:	learn: 495.7401632	total: 1.27s	remaining: 11.6s
# 99:	learn: 495.3954401	total: 1.28s	remaining: 11.6s
# 100:	learn: 495.2168461	total: 1.29s	remaining: 11.5s
# 101:	learn: 494.9583820	total: 1.3s	remaining: 11.5s
# 102:	learn: 494.5971576	total: 1.32s	remaining: 11.5s
# 103:	learn: 494.4309213	total: 1.33s	remaining: 11.4s
# 104:	learn: 494.2301800	total: 1.34s	remaining: 11.4s
# 105:	learn: 493.8114501	total: 1.35s	remaining: 11.4s
# 106:	learn: 493.4308762	total: 1.36s	remaining: 11.3s
# 107:	learn: 493.3375196	total: 1.37s	remaining: 11.3s
# 108:	learn: 493.1130385	total: 1.38s	remaining: 11.3s
# 109:	learn: 492.6834717	total: 1.39s	remaining: 11.2s
# 110:	learn: 492.4284453	total: 1.4s	remaining: 11.2s
# 111:	learn: 492.1399673	total: 1.41s	remaining: 11.2s
# 112:	learn: 491.8405674	total: 1.42s	remaining: 11.1s
# 113:	learn: 491.4026967	total: 1.43s	remaining: 11.1s
# 114:	learn: 490.8224795	total: 1.44s	remaining: 11.1s
# 115:	learn: 490.6114999	total: 1.45s	remaining: 11.1s
# 116:	learn: 490.2616804	total: 1.46s	remaining: 11s
# 117:	learn: 489.9183584	total: 1.47s	remaining: 11s
# 118:	learn: 489.3842420	total: 1.48s	remaining: 11s
# 119:	learn: 489.2072593	total: 1.49s	remaining: 10.9s
# 120:	learn: 488.9586821	total: 1.5s	remaining: 10.9s
# 121:	learn: 488.6843424	total: 1.51s	remaining: 10.9s
# 122:	learn: 488.2628500	total: 1.52s	remaining: 10.9s
# 123:	learn: 487.7932980	total: 1.53s	remaining: 10.8s
# 124:	learn: 487.4642517	total: 1.55s	remaining: 10.8s
# 125:	learn: 487.2394562	total: 1.56s	remaining: 10.8s
# 126:	learn: 486.9943957	total: 1.57s	remaining: 10.8s
# 127:	learn: 486.6166573	total: 1.58s	remaining: 10.8s
# 128:	learn: 486.3218008	total: 1.59s	remaining: 10.7s
# 129:	learn: 486.0874047	total: 1.6s	remaining: 10.7s
# 130:	learn: 485.7793477	total: 1.61s	remaining: 10.7s
# 131:	learn: 485.2555441	total: 1.62s	remaining: 10.7s
# 132:	learn: 484.8825081	total: 1.64s	remaining: 10.7s
# 133:	learn: 484.6432472	total: 1.65s	remaining: 10.7s
# 134:	learn: 484.3251859	total: 1.66s	remaining: 10.6s
# 135:	learn: 483.9319185	total: 1.67s	remaining: 10.6s
# 136:	learn: 483.6992970	total: 1.69s	remaining: 10.6s
# 137:	learn: 483.5698054	total: 1.7s	remaining: 10.6s
# 138:	learn: 483.3528874	total: 1.71s	remaining: 10.6s
# 139:	learn: 483.1427311	total: 1.72s	remaining: 10.6s
# 140:	learn: 482.8562215	total: 1.73s	remaining: 10.6s
# 141:	learn: 482.4991184	total: 1.75s	remaining: 10.5s
# 142:	learn: 482.0896327	total: 1.76s	remaining: 10.5s
# 143:	learn: 481.8719026	total: 1.77s	remaining: 10.5s
# 144:	learn: 481.5041219	total: 1.78s	remaining: 10.5s
# 145:	learn: 481.3160642	total: 1.79s	remaining: 10.5s
# 146:	learn: 481.0766900	total: 1.8s	remaining: 10.4s
# 147:	learn: 480.8028058	total: 1.81s	remaining: 10.4s
# 148:	learn: 480.5056507	total: 1.82s	remaining: 10.4s
# 149:	learn: 480.2662877	total: 1.83s	remaining: 10.4s
# 150:	learn: 479.9270364	total: 1.84s	remaining: 10.4s
# 151:	learn: 479.6182041	total: 1.86s	remaining: 10.4s
# 152:	learn: 479.2963859	total: 1.87s	remaining: 10.3s
# 153:	learn: 478.6844424	total: 1.88s	remaining: 10.3s
# 154:	learn: 478.4115956	total: 1.89s	remaining: 10.3s
# 155:	learn: 477.9440538	total: 1.9s	remaining: 10.3s
# 156:	learn: 477.7118129	total: 1.91s	remaining: 10.3s
# 157:	learn: 477.4067043	total: 1.92s	remaining: 10.3s
# 158:	learn: 477.1680723	total: 1.94s	remaining: 10.2s
# 159:	learn: 476.8336031	total: 1.95s	remaining: 10.2s
# 160:	learn: 476.4560162	total: 1.96s	remaining: 10.2s
# 161:	learn: 476.2569340	total: 1.97s	remaining: 10.2s
# 162:	learn: 475.9964432	total: 1.98s	remaining: 10.2s
# 163:	learn: 475.7450002	total: 2s	remaining: 10.2s
# 164:	learn: 475.6112794	total: 2.01s	remaining: 10.2s
# 165:	learn: 475.1175482	total: 2.02s	remaining: 10.2s
# 166:	learn: 474.8821923	total: 2.03s	remaining: 10.1s
# 167:	learn: 474.3279696	total: 2.04s	remaining: 10.1s
# 168:	learn: 473.9978291	total: 2.06s	remaining: 10.1s
# 169:	learn: 473.4452129	total: 2.07s	remaining: 10.1s
# 170:	learn: 472.9407572	total: 2.08s	remaining: 10.1s
# 171:	learn: 472.5980271	total: 2.09s	remaining: 10.1s
# 172:	learn: 472.3840996	total: 2.1s	remaining: 10.1s
# 173:	learn: 472.0175250	total: 2.12s	remaining: 10s
# 174:	learn: 471.5801272	total: 2.13s	remaining: 10s
# 175:	learn: 471.3487002	total: 2.14s	remaining: 10s
# 176:	learn: 471.0049251	total: 2.15s	remaining: 10s
# 177:	learn: 470.7471410	total: 2.16s	remaining: 9.99s
# 178:	learn: 470.3653775	total: 2.18s	remaining: 9.99s
# 179:	learn: 470.1538610	total: 2.19s	remaining: 9.98s
# 180:	learn: 469.9736912	total: 2.2s	remaining: 9.97s
# 181:	learn: 469.5955726	total: 2.22s	remaining: 9.97s
# 182:	learn: 469.1651723	total: 2.23s	remaining: 9.95s
# 183:	learn: 468.8739005	total: 2.24s	remaining: 9.95s
# 184:	learn: 468.4739811	total: 2.26s	remaining: 9.94s
# 185:	learn: 467.8633061	total: 2.27s	remaining: 9.93s
# 186:	learn: 467.4240247	total: 2.29s	remaining: 9.94s
# 187:	learn: 467.1492161	total: 2.3s	remaining: 9.93s
# 188:	learn: 466.8005705	total: 2.31s	remaining: 9.91s
# 189:	learn: 466.4592897	total: 2.32s	remaining: 9.91s
# 190:	learn: 466.2606392	total: 2.33s	remaining: 9.89s
# 191:	learn: 465.9179755	total: 2.35s	remaining: 9.88s
# 192:	learn: 465.7476291	total: 2.36s	remaining: 9.87s
# 193:	learn: 465.2831822	total: 2.37s	remaining: 9.86s
# 194:	learn: 464.8121808	total: 2.39s	remaining: 9.86s
# 195:	learn: 464.5340066	total: 2.4s	remaining: 9.85s
# 196:	learn: 464.1370847	total: 2.41s	remaining: 9.84s
# 197:	learn: 463.8969885	total: 2.42s	remaining: 9.83s
# 198:	learn: 463.5222152	total: 2.44s	remaining: 9.82s
# 199:	learn: 463.2194185	total: 2.45s	remaining: 9.81s
# 200:	learn: 462.8570377	total: 2.46s	remaining: 9.79s
# 201:	learn: 462.6047501	total: 2.48s	remaining: 9.79s
# 202:	learn: 462.1945765	total: 2.49s	remaining: 9.77s
# 203:	learn: 461.8870298	total: 2.5s	remaining: 9.76s
# 204:	learn: 461.6322154	total: 2.51s	remaining: 9.75s
# 205:	learn: 461.4386069	total: 2.53s	remaining: 9.74s
# 206:	learn: 461.1167591	total: 2.54s	remaining: 9.72s
# 207:	learn: 460.8377880	total: 2.55s	remaining: 9.71s
# 208:	learn: 460.5962105	total: 2.56s	remaining: 9.7s
# 209:	learn: 460.2610799	total: 2.58s	remaining: 9.69s
# 210:	learn: 459.9438566	total: 2.59s	remaining: 9.68s
# 211:	learn: 459.6360176	total: 2.6s	remaining: 9.67s
# 212:	learn: 459.3628121	total: 2.61s	remaining: 9.65s
# 213:	learn: 459.1482711	total: 2.62s	remaining: 9.64s
# 214:	learn: 458.8064372	total: 2.63s	remaining: 9.62s
# 215:	learn: 458.6567653	total: 2.65s	remaining: 9.61s
# 216:	learn: 458.4415789	total: 2.66s	remaining: 9.59s
# 217:	learn: 458.1001469	total: 2.67s	remaining: 9.58s
# 218:	learn: 457.7249408	total: 2.68s	remaining: 9.56s
# 219:	learn: 457.4967765	total: 2.69s	remaining: 9.55s
# 220:	learn: 457.2821473	total: 2.7s	remaining: 9.53s
# 221:	learn: 457.1039016	total: 2.72s	remaining: 9.52s
# 222:	learn: 456.7280030	total: 2.73s	remaining: 9.5s
# 223:	learn: 456.2275482	total: 2.74s	remaining: 9.48s
# 224:	learn: 455.9250331	total: 2.75s	remaining: 9.46s
# 225:	learn: 455.6764570	total: 2.76s	remaining: 9.45s
# 226:	learn: 455.3928281	total: 2.77s	remaining: 9.43s
# 227:	learn: 455.0688077	total: 2.78s	remaining: 9.42s
# 228:	learn: 454.7609820	total: 2.79s	remaining: 9.4s
# 229:	learn: 454.4427515	total: 2.81s	remaining: 9.39s
# 230:	learn: 454.1899364	total: 2.82s	remaining: 9.38s
# 231:	learn: 453.9286685	total: 2.83s	remaining: 9.37s
# 232:	learn: 453.7453639	total: 2.84s	remaining: 9.35s
# 233:	learn: 453.3962907	total: 2.85s	remaining: 9.34s
# 234:	learn: 453.1994987	total: 2.86s	remaining: 9.32s
# 235:	learn: 452.8692731	total: 2.88s	remaining: 9.31s
# 236:	learn: 452.6598614	total: 2.89s	remaining: 9.3s
# 237:	learn: 452.2434687	total: 2.9s	remaining: 9.28s
# 238:	learn: 451.9090959	total: 2.91s	remaining: 9.27s
# 239:	learn: 451.5233699	total: 2.92s	remaining: 9.25s
# 240:	learn: 451.2051488	total: 2.93s	remaining: 9.24s
# 241:	learn: 450.7759077	total: 2.94s	remaining: 9.23s
# 242:	learn: 450.4316275	total: 2.96s	remaining: 9.21s
# 243:	learn: 450.2272731	total: 2.97s	remaining: 9.2s
# 244:	learn: 449.9483733	total: 2.98s	remaining: 9.19s
# 245:	learn: 449.7492670	total: 2.99s	remaining: 9.17s
# 246:	learn: 449.5683014	total: 3s	remaining: 9.15s
# 247:	learn: 449.3617641	total: 3.01s	remaining: 9.14s
# 248:	learn: 449.1762997	total: 3.03s	remaining: 9.13s
# 249:	learn: 448.9987122	total: 3.04s	remaining: 9.11s
# 250:	learn: 448.6703144	total: 3.05s	remaining: 9.1s
# 251:	learn: 448.5158975	total: 3.06s	remaining: 9.09s
# 252:	learn: 448.2778238	total: 3.07s	remaining: 9.07s
# 253:	learn: 448.1581078	total: 3.08s	remaining: 9.05s
# 254:	learn: 447.9486331	total: 3.09s	remaining: 9.04s
# 255:	learn: 447.6418713	total: 3.1s	remaining: 9.03s
# 256:	learn: 447.3802586	total: 3.12s	remaining: 9.01s
# 257:	learn: 447.2171447	total: 3.13s	remaining: 9s
# 258:	learn: 446.9385352	total: 3.14s	remaining: 8.99s
# 259:	learn: 446.5422443	total: 3.15s	remaining: 8.97s
# 260:	learn: 446.2810384	total: 3.16s	remaining: 8.96s
# 261:	learn: 446.0095008	total: 3.17s	remaining: 8.94s
# 262:	learn: 445.6008043	total: 3.19s	remaining: 8.93s
# 263:	learn: 445.4510320	total: 3.2s	remaining: 8.91s
# 264:	learn: 445.1736948	total: 3.21s	remaining: 8.9s
# 265:	learn: 445.0149366	total: 3.22s	remaining: 8.89s
# 266:	learn: 444.9167719	total: 3.24s	remaining: 8.89s
# 267:	learn: 444.6760605	total: 3.25s	remaining: 8.88s
# 268:	learn: 444.3918164	total: 3.26s	remaining: 8.86s
# 269:	learn: 444.0010119	total: 3.27s	remaining: 8.85s
# 270:	learn: 443.5861791	total: 3.29s	remaining: 8.84s
# 271:	learn: 443.4164423	total: 3.3s	remaining: 8.82s
# 272:	learn: 443.0224502	total: 3.31s	remaining: 8.81s
# 273:	learn: 442.7859818	total: 3.32s	remaining: 8.79s
# 274:	learn: 442.4711815	total: 3.33s	remaining: 8.78s
# 275:	learn: 442.2396422	total: 3.34s	remaining: 8.76s
# 276:	learn: 442.0919452	total: 3.35s	remaining: 8.74s
# 277:	learn: 441.8289995	total: 3.36s	remaining: 8.73s
# 278:	learn: 441.6639807	total: 3.37s	remaining: 8.71s
# 279:	learn: 441.3399900	total: 3.38s	remaining: 8.7s
# 280:	learn: 441.0165977	total: 3.4s	remaining: 8.69s
# 281:	learn: 440.7604363	total: 3.41s	remaining: 8.67s
# 282:	learn: 440.5511064	total: 3.42s	remaining: 8.66s
# 283:	learn: 440.2782947	total: 3.43s	remaining: 8.64s
# 284:	learn: 440.0277403	total: 3.44s	remaining: 8.63s
# 285:	learn: 439.7290174	total: 3.45s	remaining: 8.62s
# 286:	learn: 439.3957845	total: 3.47s	remaining: 8.61s
# 287:	learn: 439.1190781	total: 3.48s	remaining: 8.6s
# 288:	learn: 438.7984897	total: 3.49s	remaining: 8.59s
# 289:	learn: 438.6674295	total: 3.5s	remaining: 8.57s
# 290:	learn: 438.4606661	total: 3.51s	remaining: 8.56s
# 291:	learn: 438.3136193	total: 3.52s	remaining: 8.54s
# 292:	learn: 438.1895815	total: 3.53s	remaining: 8.53s
# 293:	learn: 437.9637092	total: 3.54s	remaining: 8.51s
# 294:	learn: 437.6318156	total: 3.56s	remaining: 8.5s
# 295:	learn: 437.4175755	total: 3.57s	remaining: 8.48s
# 296:	learn: 437.2998865	total: 3.58s	remaining: 8.46s
# 297:	learn: 437.0528189	total: 3.59s	remaining: 8.45s
# 298:	learn: 436.8878015	total: 3.6s	remaining: 8.44s
# 299:	learn: 436.6198444	total: 3.61s	remaining: 8.42s
# 300:	learn: 436.3859338	total: 3.62s	remaining: 8.41s
# 301:	learn: 436.1036151	total: 3.63s	remaining: 8.39s
# 302:	learn: 435.7757410	total: 3.64s	remaining: 8.38s
# 303:	learn: 435.5726435	total: 3.65s	remaining: 8.37s
# 304:	learn: 435.2365550	total: 3.67s	remaining: 8.36s
# 305:	learn: 435.1072128	total: 3.68s	remaining: 8.34s
# 306:	learn: 434.8667730	total: 3.69s	remaining: 8.32s
# 307:	learn: 434.6088342	total: 3.7s	remaining: 8.3s
# 308:	learn: 434.3628052	total: 3.71s	remaining: 8.29s
# 309:	learn: 434.0992513	total: 3.72s	remaining: 8.27s
# 310:	learn: 433.9577561	total: 3.73s	remaining: 8.26s
# 311:	learn: 433.7624101	total: 3.74s	remaining: 8.24s
# 312:	learn: 433.5010757	total: 3.75s	remaining: 8.22s
# 313:	learn: 433.3536645	total: 3.76s	remaining: 8.21s
# 314:	learn: 433.2398508	total: 3.77s	remaining: 8.19s
# 315:	learn: 432.9633833	total: 3.78s	remaining: 8.17s
# 316:	learn: 432.7872835	total: 3.79s	remaining: 8.16s
# 317:	learn: 432.5807507	total: 3.8s	remaining: 8.14s
# 318:	learn: 432.2834930	total: 3.81s	remaining: 8.13s
# 319:	learn: 431.8565081	total: 3.82s	remaining: 8.12s
# 320:	learn: 431.6424221	total: 3.83s	remaining: 8.1s
# 321:	learn: 431.2908306	total: 3.84s	remaining: 8.09s
# 322:	learn: 431.2054175	total: 3.86s	remaining: 8.08s
# 323:	learn: 430.9659368	total: 3.87s	remaining: 8.07s
# 324:	learn: 430.7969210	total: 3.88s	remaining: 8.07s
# 325:	learn: 430.4991919	total: 3.9s	remaining: 8.06s
# 326:	learn: 430.3183644	total: 3.91s	remaining: 8.04s
# 327:	learn: 430.1906365	total: 3.92s	remaining: 8.03s
# 328:	learn: 429.9988789	total: 3.93s	remaining: 8.02s
# 329:	learn: 429.6737308	total: 3.94s	remaining: 8s
# 330:	learn: 429.4505954	total: 3.95s	remaining: 7.99s
# 331:	learn: 429.2662055	total: 3.96s	remaining: 7.97s
# 332:	learn: 428.9759918	total: 3.97s	remaining: 7.96s
# 333:	learn: 428.7287532	total: 3.98s	remaining: 7.94s
# 334:	learn: 428.5046760	total: 3.99s	remaining: 7.93s
# 335:	learn: 428.3309771	total: 4s	remaining: 7.91s
# 336:	learn: 428.0697623	total: 4.01s	remaining: 7.89s
# 337:	learn: 427.8804934	total: 4.02s	remaining: 7.88s
# 338:	learn: 427.6332120	total: 4.03s	remaining: 7.87s
# 339:	learn: 427.5014260	total: 4.04s	remaining: 7.85s
# 340:	learn: 427.3527822	total: 4.05s	remaining: 7.83s
# 341:	learn: 427.0814309	total: 4.06s	remaining: 7.82s
# 342:	learn: 426.8069782	total: 4.07s	remaining: 7.8s
# 343:	learn: 426.5466711	total: 4.08s	remaining: 7.79s
# 344:	learn: 426.3083804	total: 4.09s	remaining: 7.77s
# 345:	learn: 426.1249146	total: 4.1s	remaining: 7.75s
# 346:	learn: 425.9087742	total: 4.11s	remaining: 7.74s
# 347:	learn: 425.7010485	total: 4.12s	remaining: 7.72s
# 348:	learn: 425.4762555	total: 4.13s	remaining: 7.71s
# 349:	learn: 425.2247127	total: 4.14s	remaining: 7.69s
# 350:	learn: 424.9704597	total: 4.15s	remaining: 7.68s
# 351:	learn: 424.7289768	total: 4.16s	remaining: 7.66s
# 352:	learn: 424.3745212	total: 4.17s	remaining: 7.65s
# 353:	learn: 424.1085246	total: 4.18s	remaining: 7.63s
# 354:	learn: 423.9359495	total: 4.19s	remaining: 7.62s
# 355:	learn: 423.7250722	total: 4.2s	remaining: 7.6s
# 356:	learn: 423.5565600	total: 4.21s	remaining: 7.59s
# 357:	learn: 423.1685157	total: 4.22s	remaining: 7.57s
# 358:	learn: 423.0073784	total: 4.23s	remaining: 7.55s
# 359:	learn: 422.8018773	total: 4.24s	remaining: 7.54s
# 360:	learn: 422.5605868	total: 4.25s	remaining: 7.53s
# 361:	learn: 422.3103311	total: 4.26s	remaining: 7.52s
# 362:	learn: 421.9422434	total: 4.28s	remaining: 7.5s
# 363:	learn: 421.7116489	total: 4.29s	remaining: 7.49s
# 364:	learn: 421.3442767	total: 4.3s	remaining: 7.47s
# 365:	learn: 421.1957988	total: 4.31s	remaining: 7.46s
# 366:	learn: 420.8275393	total: 4.32s	remaining: 7.45s
# 367:	learn: 420.7521220	total: 4.33s	remaining: 7.43s
# 368:	learn: 420.4588167	total: 4.34s	remaining: 7.42s
# 369:	learn: 420.2836629	total: 4.35s	remaining: 7.4s
# 370:	learn: 420.2173010	total: 4.36s	remaining: 7.39s
# 371:	learn: 420.0892408	total: 4.37s	remaining: 7.38s
# 372:	learn: 419.8741634	total: 4.38s	remaining: 7.36s
# 373:	learn: 419.5969294	total: 4.4s	remaining: 7.36s
# 374:	learn: 419.3523620	total: 4.41s	remaining: 7.36s
# 375:	learn: 419.0684202	total: 4.43s	remaining: 7.35s
# 376:	learn: 418.9145535	total: 4.45s	remaining: 7.35s
# 377:	learn: 418.6160927	total: 4.46s	remaining: 7.34s
# 378:	learn: 418.3662713	total: 4.48s	remaining: 7.34s
# 379:	learn: 418.1632984	total: 4.5s	remaining: 7.34s
# 380:	learn: 417.9105801	total: 4.51s	remaining: 7.34s
# 381:	learn: 417.7004234	total: 4.54s	remaining: 7.34s
# 382:	learn: 417.5267929	total: 4.56s	remaining: 7.34s
# 383:	learn: 417.3374551	total: 4.58s	remaining: 7.35s
# 384:	learn: 417.1181299	total: 4.6s	remaining: 7.35s
# 385:	learn: 416.9693764	total: 4.62s	remaining: 7.34s
# 386:	learn: 416.7302122	total: 4.63s	remaining: 7.34s
# 387:	learn: 416.4957315	total: 4.65s	remaining: 7.34s
# 388:	learn: 416.2813100	total: 4.67s	remaining: 7.34s
# 389:	learn: 415.9813988	total: 4.7s	remaining: 7.35s
# 390:	learn: 415.6739167	total: 4.72s	remaining: 7.34s
# 391:	learn: 415.4453328	total: 4.74s	remaining: 7.34s
# 392:	learn: 415.2081574	total: 4.75s	remaining: 7.34s
# 393:	learn: 415.0046501	total: 4.77s	remaining: 7.34s
# 394:	learn: 414.8343104	total: 4.79s	remaining: 7.33s
# 395:	learn: 414.6685378	total: 4.81s	remaining: 7.33s
# 396:	learn: 414.4432900	total: 4.82s	remaining: 7.33s
# 397:	learn: 414.1628505	total: 4.84s	remaining: 7.32s
# 398:	learn: 413.9511173	total: 4.86s	remaining: 7.32s
# 399:	learn: 413.7607502	total: 4.87s	remaining: 7.31s
# 400:	learn: 413.6496754	total: 4.89s	remaining: 7.31s
# 401:	learn: 413.5743113	total: 4.91s	remaining: 7.3s
# 402:	learn: 413.3202337	total: 4.92s	remaining: 7.3s
# 403:	learn: 413.1061847	total: 4.94s	remaining: 7.29s
# 404:	learn: 412.8933808	total: 4.96s	remaining: 7.28s
# 405:	learn: 412.7189448	total: 4.97s	remaining: 7.28s
# 406:	learn: 412.5970844	total: 4.99s	remaining: 7.28s
# 407:	learn: 412.2821831	total: 5.01s	remaining: 7.28s
# 408:	learn: 412.2154099	total: 5.03s	remaining: 7.27s
# 409:	learn: 411.9646891	total: 5.05s	remaining: 7.26s
# 410:	learn: 411.8361271	total: 5.07s	remaining: 7.26s
# 411:	learn: 411.7377241	total: 5.08s	remaining: 7.25s
# 412:	learn: 411.4887082	total: 5.1s	remaining: 7.25s
# 413:	learn: 411.4324120	total: 5.12s	remaining: 7.24s
# 414:	learn: 411.2843201	total: 5.13s	remaining: 7.23s
# 415:	learn: 411.1019523	total: 5.14s	remaining: 7.22s
# 416:	learn: 410.9532897	total: 5.16s	remaining: 7.21s
# 417:	learn: 410.7021929	total: 5.17s	remaining: 7.2s
# 418:	learn: 410.4938707	total: 5.18s	remaining: 7.19s
# 419:	learn: 410.2770331	total: 5.19s	remaining: 7.17s
# 420:	learn: 410.0321713	total: 5.2s	remaining: 7.16s
# 421:	learn: 409.9064581	total: 5.21s	remaining: 7.14s
# 422:	learn: 409.7836414	total: 5.23s	remaining: 7.13s
# 423:	learn: 409.6740179	total: 5.24s	remaining: 7.11s
# 424:	learn: 409.3617098	total: 5.25s	remaining: 7.1s
# 425:	learn: 409.2250585	total: 5.26s	remaining: 7.08s
# 426:	learn: 409.0831119	total: 5.27s	remaining: 7.07s
# 427:	learn: 408.8352605	total: 5.28s	remaining: 7.05s
# 428:	learn: 408.6456663	total: 5.29s	remaining: 7.04s
# 429:	learn: 408.5112238	total: 5.3s	remaining: 7.03s
# 430:	learn: 408.3314167	total: 5.31s	remaining: 7.01s
# 431:	learn: 408.0969206	total: 5.32s	remaining: 7s
# 432:	learn: 407.8495255	total: 5.33s	remaining: 6.98s
# 433:	learn: 407.7623701	total: 5.34s	remaining: 6.97s
# 434:	learn: 407.5989026	total: 5.36s	remaining: 6.96s
# 435:	learn: 407.5068386	total: 5.37s	remaining: 6.94s
# 436:	learn: 407.3844505	total: 5.38s	remaining: 6.93s
# 437:	learn: 407.1513541	total: 5.39s	remaining: 6.91s
# 438:	learn: 407.0530240	total: 5.4s	remaining: 6.9s
# 439:	learn: 406.7451853	total: 5.41s	remaining: 6.88s
# 440:	learn: 406.5235058	total: 5.42s	remaining: 6.87s
# 441:	learn: 406.3444281	total: 5.43s	remaining: 6.86s
# 442:	learn: 406.2537963	total: 5.44s	remaining: 6.84s
# 443:	learn: 406.0054559	total: 5.45s	remaining: 6.83s
# 444:	learn: 405.9023183	total: 5.46s	remaining: 6.81s
# 445:	learn: 405.6519322	total: 5.47s	remaining: 6.8s
# 446:	learn: 405.5147494	total: 5.48s	remaining: 6.78s
# 447:	learn: 405.3815232	total: 5.49s	remaining: 6.77s
# 448:	learn: 405.1037276	total: 5.5s	remaining: 6.75s
# 449:	learn: 404.9749948	total: 5.51s	remaining: 6.74s
# 450:	learn: 404.7878637	total: 5.52s	remaining: 6.72s
# 451:	learn: 404.5113685	total: 5.53s	remaining: 6.71s
# 452:	learn: 404.2232765	total: 5.54s	remaining: 6.7s
# 453:	learn: 404.0534444	total: 5.56s	remaining: 6.68s
# 454:	learn: 403.9094749	total: 5.57s	remaining: 6.67s
# 455:	learn: 403.6958256	total: 5.58s	remaining: 6.65s
# 456:	learn: 403.6117193	total: 5.59s	remaining: 6.64s
# 457:	learn: 403.3833068	total: 5.6s	remaining: 6.63s
# 458:	learn: 403.1799675	total: 5.61s	remaining: 6.61s
# 459:	learn: 402.9023789	total: 5.62s	remaining: 6.6s
# 460:	learn: 402.7760868	total: 5.63s	remaining: 6.58s
# 461:	learn: 402.6797967	total: 5.64s	remaining: 6.57s
# 462:	learn: 402.4365205	total: 5.65s	remaining: 6.55s
# 463:	learn: 402.3394382	total: 5.66s	remaining: 6.54s
# 464:	learn: 402.2398577	total: 5.67s	remaining: 6.53s
# 465:	learn: 401.9135396	total: 5.68s	remaining: 6.51s
# 466:	learn: 401.7160774	total: 5.69s	remaining: 6.5s
# 467:	learn: 401.5565965	total: 5.7s	remaining: 6.48s
# 468:	learn: 401.4391104	total: 5.71s	remaining: 6.47s
# 469:	learn: 401.2504180	total: 5.72s	remaining: 6.45s
# 470:	learn: 401.0475952	total: 5.73s	remaining: 6.44s
# 471:	learn: 400.9203108	total: 5.74s	remaining: 6.42s
# 472:	learn: 400.6834011	total: 5.75s	remaining: 6.41s
# 473:	learn: 400.4783450	total: 5.76s	remaining: 6.39s
# 474:	learn: 400.3534492	total: 5.77s	remaining: 6.38s
# 475:	learn: 400.1749199	total: 5.78s	remaining: 6.36s
# 476:	learn: 400.0328443	total: 5.8s	remaining: 6.36s
# 477:	learn: 399.7747658	total: 5.81s	remaining: 6.34s
# 478:	learn: 399.5659837	total: 5.82s	remaining: 6.33s
# 479:	learn: 399.3321826	total: 5.83s	remaining: 6.32s
# 480:	learn: 399.2272599	total: 5.84s	remaining: 6.3s
# 481:	learn: 399.0450623	total: 5.85s	remaining: 6.29s
# 482:	learn: 398.9426321	total: 5.87s	remaining: 6.28s
# 483:	learn: 398.6802914	total: 5.88s	remaining: 6.27s
# 484:	learn: 398.5125908	total: 5.89s	remaining: 6.25s
# 485:	learn: 398.3256040	total: 5.9s	remaining: 6.24s
# 486:	learn: 398.1044545	total: 5.91s	remaining: 6.23s
# 487:	learn: 397.8801620	total: 5.93s	remaining: 6.22s
# 488:	learn: 397.7055834	total: 5.94s	remaining: 6.21s
# 489:	learn: 397.5181640	total: 5.95s	remaining: 6.19s
# 490:	learn: 397.3148382	total: 5.96s	remaining: 6.18s
# 491:	learn: 397.1491292	total: 5.97s	remaining: 6.16s
# 492:	learn: 396.9592068	total: 5.98s	remaining: 6.15s
# 493:	learn: 396.7883563	total: 5.99s	remaining: 6.14s
# 494:	learn: 396.5738798	total: 6s	remaining: 6.13s
# 495:	learn: 396.3190684	total: 6.02s	remaining: 6.11s
# 496:	learn: 396.2233666	total: 6.03s	remaining: 6.1s
# 497:	learn: 395.9951056	total: 6.04s	remaining: 6.09s
# 498:	learn: 395.8118566	total: 6.05s	remaining: 6.07s
# 499:	learn: 395.7335986	total: 6.06s	remaining: 6.06s
# 500:	learn: 395.5481714	total: 6.07s	remaining: 6.05s
# 501:	learn: 395.3927829	total: 6.08s	remaining: 6.03s
# 502:	learn: 395.2727877	total: 6.09s	remaining: 6.02s
# 503:	learn: 395.0600088	total: 6.1s	remaining: 6.01s
# 504:	learn: 394.7800188	total: 6.11s	remaining: 5.99s
# 505:	learn: 394.5586944	total: 6.12s	remaining: 5.98s
# 506:	learn: 394.3300862	total: 6.13s	remaining: 5.96s
# 507:	learn: 394.1940928	total: 6.14s	remaining: 5.95s
# 508:	learn: 393.9486729	total: 6.15s	remaining: 5.94s
# 509:	learn: 393.7769716	total: 6.16s	remaining: 5.92s
# 510:	learn: 393.5755932	total: 6.17s	remaining: 5.91s
# 511:	learn: 393.3650163	total: 6.19s	remaining: 5.9s
# 512:	learn: 393.1783374	total: 6.2s	remaining: 5.88s
# 513:	learn: 393.0356896	total: 6.21s	remaining: 5.87s
# 514:	learn: 392.8852323	total: 6.22s	remaining: 5.86s
# 515:	learn: 392.7552198	total: 6.23s	remaining: 5.84s
# 516:	learn: 392.5929547	total: 6.24s	remaining: 5.83s
# 517:	learn: 392.3756229	total: 6.25s	remaining: 5.82s
# 518:	learn: 392.1749558	total: 6.26s	remaining: 5.8s
# 519:	learn: 391.9934085	total: 6.27s	remaining: 5.79s
# 520:	learn: 391.6665462	total: 6.28s	remaining: 5.77s
# 521:	learn: 391.4652052	total: 6.29s	remaining: 5.76s
# 522:	learn: 391.2414855	total: 6.3s	remaining: 5.75s
# 523:	learn: 391.0172306	total: 6.31s	remaining: 5.73s
# 524:	learn: 390.8800617	total: 6.32s	remaining: 5.72s
# 525:	learn: 390.6947037	total: 6.33s	remaining: 5.71s
# 526:	learn: 390.4499210	total: 6.34s	remaining: 5.69s
# 527:	learn: 390.3053722	total: 6.35s	remaining: 5.68s
# 528:	learn: 390.2112314	total: 6.37s	remaining: 5.67s
# 529:	learn: 389.9502092	total: 6.38s	remaining: 5.65s
# 530:	learn: 389.7875940	total: 6.39s	remaining: 5.64s
# 531:	learn: 389.5147455	total: 6.4s	remaining: 5.63s
# 532:	learn: 389.3269492	total: 6.41s	remaining: 5.61s
# 533:	learn: 389.0497776	total: 6.42s	remaining: 5.6s
# 534:	learn: 388.8838821	total: 6.43s	remaining: 5.59s
# 535:	learn: 388.7119650	total: 6.44s	remaining: 5.57s
# 536:	learn: 388.5643943	total: 6.45s	remaining: 5.56s
# 537:	learn: 388.4278640	total: 6.46s	remaining: 5.55s
# 538:	learn: 388.2850089	total: 6.47s	remaining: 5.53s
# 539:	learn: 388.1139353	total: 6.48s	remaining: 5.52s
# 540:	learn: 387.9678398	total: 6.49s	remaining: 5.51s
# 541:	learn: 387.8956558	total: 6.5s	remaining: 5.49s
# 542:	learn: 387.7808359	total: 6.51s	remaining: 5.48s
# 543:	learn: 387.6257736	total: 6.52s	remaining: 5.46s
# 544:	learn: 387.5018557	total: 6.53s	remaining: 5.45s
# 545:	learn: 387.3663046	total: 6.54s	remaining: 5.44s
# 546:	learn: 387.2837993	total: 6.55s	remaining: 5.42s
# 547:	learn: 387.1391525	total: 6.56s	remaining: 5.41s
# 548:	learn: 387.0354553	total: 6.57s	remaining: 5.4s
# 549:	learn: 386.7934599	total: 6.58s	remaining: 5.38s
# 550:	learn: 386.6518508	total: 6.59s	remaining: 5.37s
# 551:	learn: 386.4361221	total: 6.6s	remaining: 5.36s
# 552:	learn: 386.2569053	total: 6.61s	remaining: 5.35s
# 553:	learn: 386.0220390	total: 6.63s	remaining: 5.33s
# 554:	learn: 385.8203550	total: 6.64s	remaining: 5.32s
# 555:	learn: 385.6745059	total: 6.65s	remaining: 5.31s
# 556:	learn: 385.5410695	total: 6.66s	remaining: 5.3s
# 557:	learn: 385.3593463	total: 6.67s	remaining: 5.29s
# 558:	learn: 385.1963726	total: 6.68s	remaining: 5.27s
# 559:	learn: 385.0901885	total: 6.7s	remaining: 5.26s
# 560:	learn: 385.0386603	total: 6.71s	remaining: 5.25s
# 561:	learn: 384.7972153	total: 6.72s	remaining: 5.24s
# 562:	learn: 384.5965736	total: 6.73s	remaining: 5.22s
# 563:	learn: 384.4337296	total: 6.74s	remaining: 5.21s
# 564:	learn: 384.2258330	total: 6.75s	remaining: 5.2s
# 565:	learn: 384.0843869	total: 6.76s	remaining: 5.19s
# 566:	learn: 383.8315125	total: 6.78s	remaining: 5.17s
# 567:	learn: 383.6067024	total: 6.79s	remaining: 5.16s
# 568:	learn: 383.5020307	total: 6.8s	remaining: 5.15s
# 569:	learn: 383.2929981	total: 6.81s	remaining: 5.14s
# 570:	learn: 383.0755977	total: 6.82s	remaining: 5.12s
# 571:	learn: 382.7905665	total: 6.83s	remaining: 5.11s
# 572:	learn: 382.5964993	total: 6.84s	remaining: 5.1s
# 573:	learn: 382.4687213	total: 6.85s	remaining: 5.08s
# 574:	learn: 382.3517220	total: 6.86s	remaining: 5.07s
# 575:	learn: 382.1768928	total: 6.87s	remaining: 5.06s
# 576:	learn: 382.0359091	total: 6.88s	remaining: 5.05s
# 577:	learn: 381.9474129	total: 6.89s	remaining: 5.03s
# 578:	learn: 381.8555117	total: 6.91s	remaining: 5.02s
# 579:	learn: 381.7003403	total: 6.92s	remaining: 5.01s
# 580:	learn: 381.5395098	total: 6.93s	remaining: 5s
# 581:	learn: 381.3851666	total: 6.94s	remaining: 4.98s
# 582:	learn: 381.1795779	total: 6.95s	remaining: 4.97s
# 583:	learn: 381.0697931	total: 6.96s	remaining: 4.96s
# 584:	learn: 380.9329311	total: 6.97s	remaining: 4.94s
# 585:	learn: 380.6905293	total: 6.98s	remaining: 4.93s
# 586:	learn: 380.5908617	total: 6.99s	remaining: 4.92s
# 587:	learn: 380.4263509	total: 7s	remaining: 4.9s
# 588:	learn: 380.2423392	total: 7.01s	remaining: 4.89s
# 589:	learn: 380.1507411	total: 7.02s	remaining: 4.88s
# 590:	learn: 379.9759279	total: 7.03s	remaining: 4.87s
# 591:	learn: 379.8467246	total: 7.04s	remaining: 4.85s
# 592:	learn: 379.6837242	total: 7.05s	remaining: 4.84s
# 593:	learn: 379.5556051	total: 7.06s	remaining: 4.83s
# 594:	learn: 379.3576963	total: 7.08s	remaining: 4.82s
# 595:	learn: 379.1946256	total: 7.09s	remaining: 4.8s
# 596:	learn: 379.0108833	total: 7.1s	remaining: 4.79s
# 597:	learn: 378.9386615	total: 7.11s	remaining: 4.78s
# 598:	learn: 378.7709562	total: 7.12s	remaining: 4.77s
# 599:	learn: 378.5832939	total: 7.13s	remaining: 4.75s
# 600:	learn: 378.4488891	total: 7.14s	remaining: 4.74s
# 601:	learn: 378.3237578	total: 7.15s	remaining: 4.73s
# 602:	learn: 378.1675688	total: 7.16s	remaining: 4.71s
# 603:	learn: 378.0361597	total: 7.17s	remaining: 4.7s
# 604:	learn: 377.9552848	total: 7.18s	remaining: 4.69s
# 605:	learn: 377.8006708	total: 7.19s	remaining: 4.68s
# 606:	learn: 377.6155304	total: 7.2s	remaining: 4.66s
# 607:	learn: 377.4831067	total: 7.21s	remaining: 4.65s
# 608:	learn: 377.3477173	total: 7.22s	remaining: 4.64s
# 609:	learn: 377.1583714	total: 7.23s	remaining: 4.62s
# 610:	learn: 376.9682697	total: 7.24s	remaining: 4.61s
# 611:	learn: 376.8725935	total: 7.25s	remaining: 4.6s
# 612:	learn: 376.8019097	total: 7.26s	remaining: 4.58s
# 613:	learn: 376.6833646	total: 7.27s	remaining: 4.57s
# 614:	learn: 376.4718161	total: 7.28s	remaining: 4.56s
# 615:	learn: 376.3203313	total: 7.29s	remaining: 4.54s
# 616:	learn: 376.2109885	total: 7.3s	remaining: 4.53s
# 617:	learn: 376.0491004	total: 7.31s	remaining: 4.52s
# 618:	learn: 375.8890955	total: 7.32s	remaining: 4.51s
# 619:	learn: 375.7099723	total: 7.33s	remaining: 4.49s
# 620:	learn: 375.5306435	total: 7.34s	remaining: 4.48s
# 621:	learn: 375.3311491	total: 7.36s	remaining: 4.47s
# 622:	learn: 375.0951496	total: 7.37s	remaining: 4.46s
# 623:	learn: 374.9284060	total: 7.38s	remaining: 4.45s
# 624:	learn: 374.7356200	total: 7.39s	remaining: 4.43s
# 625:	learn: 374.5307836	total: 7.4s	remaining: 4.42s
# 626:	learn: 374.4642282	total: 7.41s	remaining: 4.41s
# 627:	learn: 374.2858551	total: 7.42s	remaining: 4.39s
# 628:	learn: 374.1778792	total: 7.43s	remaining: 4.38s
# 629:	learn: 374.0205743	total: 7.44s	remaining: 4.37s
# 630:	learn: 373.9170919	total: 7.45s	remaining: 4.36s
# 631:	learn: 373.7545379	total: 7.46s	remaining: 4.34s
# 632:	learn: 373.6515820	total: 7.47s	remaining: 4.33s
# 633:	learn: 373.5671349	total: 7.49s	remaining: 4.32s
# 634:	learn: 373.4198662	total: 7.5s	remaining: 4.31s
# 635:	learn: 373.2869609	total: 7.51s	remaining: 4.3s
# 636:	learn: 373.1431074	total: 7.52s	remaining: 4.29s
# 637:	learn: 373.0385268	total: 7.54s	remaining: 4.28s
# 638:	learn: 372.8022822	total: 7.55s	remaining: 4.26s
# 639:	learn: 372.6170036	total: 7.56s	remaining: 4.25s
# 640:	learn: 372.5708202	total: 7.57s	remaining: 4.24s
# 641:	learn: 372.4675188	total: 7.59s	remaining: 4.23s
# 642:	learn: 372.3589403	total: 7.6s	remaining: 4.22s
# 643:	learn: 372.1773682	total: 7.61s	remaining: 4.21s
# 644:	learn: 371.9991184	total: 7.62s	remaining: 4.2s
# 645:	learn: 371.9050016	total: 7.64s	remaining: 4.18s
# 646:	learn: 371.7814442	total: 7.65s	remaining: 4.17s
# 647:	learn: 371.5644560	total: 7.66s	remaining: 4.16s
# 648:	learn: 371.3718099	total: 7.67s	remaining: 4.15s
# 649:	learn: 371.2712087	total: 7.68s	remaining: 4.14s
# 650:	learn: 371.1615985	total: 7.7s	remaining: 4.13s
# 651:	learn: 371.0002431	total: 7.71s	remaining: 4.11s
# 652:	learn: 370.9057002	total: 7.74s	remaining: 4.11s
# 653:	learn: 370.8231440	total: 7.76s	remaining: 4.1s
# 654:	learn: 370.7061388	total: 7.78s	remaining: 4.1s
# 655:	learn: 370.3894707	total: 7.79s	remaining: 4.09s
# 656:	learn: 370.1763431	total: 7.81s	remaining: 4.08s
# 657:	learn: 370.0157151	total: 7.82s	remaining: 4.07s
# 658:	learn: 369.8503401	total: 7.83s	remaining: 4.05s
# 659:	learn: 369.6665665	total: 7.84s	remaining: 4.04s
# 660:	learn: 369.5613561	total: 7.86s	remaining: 4.03s
# 661:	learn: 369.4836951	total: 7.87s	remaining: 4.02s
# 662:	learn: 369.3048692	total: 7.89s	remaining: 4.01s
# 663:	learn: 369.1268372	total: 7.9s	remaining: 4s
# 664:	learn: 369.0333241	total: 7.91s	remaining: 3.99s
# 665:	learn: 368.8329024	total: 7.93s	remaining: 3.98s
# 666:	learn: 368.6994571	total: 7.94s	remaining: 3.96s
# 667:	learn: 368.5617671	total: 7.96s	remaining: 3.95s
# 668:	learn: 368.3875594	total: 7.97s	remaining: 3.94s
# 669:	learn: 368.2768761	total: 7.98s	remaining: 3.93s
# 670:	learn: 368.1581247	total: 7.99s	remaining: 3.92s
# 671:	learn: 368.0331615	total: 8.01s	remaining: 3.91s
# 672:	learn: 367.9257659	total: 8.02s	remaining: 3.9s
# 673:	learn: 367.7900637	total: 8.03s	remaining: 3.89s
# 674:	learn: 367.6142114	total: 8.05s	remaining: 3.88s
# 675:	learn: 367.5214168	total: 8.06s	remaining: 3.86s
# 676:	learn: 367.3630477	total: 8.07s	remaining: 3.85s
# 677:	learn: 367.2672798	total: 8.09s	remaining: 3.84s
# 678:	learn: 367.1155229	total: 8.1s	remaining: 3.83s
# 679:	learn: 366.9681481	total: 8.11s	remaining: 3.82s
# 680:	learn: 366.8751403	total: 8.12s	remaining: 3.81s
# 681:	learn: 366.6569491	total: 8.14s	remaining: 3.79s
# 682:	learn: 366.4680812	total: 8.15s	remaining: 3.78s
# 683:	learn: 366.3127384	total: 8.16s	remaining: 3.77s
# 684:	learn: 366.1942957	total: 8.18s	remaining: 3.76s
# 685:	learn: 366.1101215	total: 8.19s	remaining: 3.75s
# 686:	learn: 365.9529539	total: 8.2s	remaining: 3.74s
# 687:	learn: 365.8390484	total: 8.22s	remaining: 3.73s
# 688:	learn: 365.6874943	total: 8.23s	remaining: 3.71s
# 689:	learn: 365.5964180	total: 8.24s	remaining: 3.7s
# 690:	learn: 365.3782245	total: 8.26s	remaining: 3.69s
# 691:	learn: 365.2949630	total: 8.27s	remaining: 3.68s
# 692:	learn: 365.0517030	total: 8.29s	remaining: 3.67s
# 693:	learn: 364.8461246	total: 8.3s	remaining: 3.66s
# 694:	learn: 364.7428228	total: 8.31s	remaining: 3.65s
# 695:	learn: 364.6459157	total: 8.32s	remaining: 3.63s
# 696:	learn: 364.5638311	total: 8.34s	remaining: 3.62s
# 697:	learn: 364.4509736	total: 8.35s	remaining: 3.61s
# 698:	learn: 364.3609392	total: 8.37s	remaining: 3.6s
# 699:	learn: 364.1872403	total: 8.39s	remaining: 3.6s
# 700:	learn: 364.1015314	total: 8.41s	remaining: 3.59s
# 701:	learn: 363.9910135	total: 8.42s	remaining: 3.58s
# 702:	learn: 363.8877252	total: 8.44s	remaining: 3.56s
# 703:	learn: 363.7845309	total: 8.45s	remaining: 3.55s
# 704:	learn: 363.6568271	total: 8.47s	remaining: 3.54s
# 705:	learn: 363.4984649	total: 8.48s	remaining: 3.53s
# 706:	learn: 363.4464192	total: 8.5s	remaining: 3.52s
# 707:	learn: 363.1689665	total: 8.51s	remaining: 3.51s
# 708:	learn: 363.0155655	total: 8.52s	remaining: 3.5s
# 709:	learn: 362.9062855	total: 8.54s	remaining: 3.49s
# 710:	learn: 362.7893028	total: 8.55s	remaining: 3.48s
# 711:	learn: 362.6847172	total: 8.56s	remaining: 3.46s
# 712:	learn: 362.5596484	total: 8.57s	remaining: 3.45s
# 713:	learn: 362.4240641	total: 8.58s	remaining: 3.44s
# 714:	learn: 362.3352943	total: 8.6s	remaining: 3.43s
# 715:	learn: 362.1087586	total: 8.61s	remaining: 3.41s
# 716:	learn: 362.0792926	total: 8.62s	remaining: 3.4s
# 717:	learn: 361.9723801	total: 8.63s	remaining: 3.39s
# 718:	learn: 361.8516079	total: 8.64s	remaining: 3.38s
# 719:	learn: 361.5944780	total: 8.66s	remaining: 3.37s
# 720:	learn: 361.3884030	total: 8.67s	remaining: 3.35s
# 721:	learn: 361.2885587	total: 8.68s	remaining: 3.34s
# 722:	learn: 361.1505401	total: 8.7s	remaining: 3.33s
# 723:	learn: 360.9609426	total: 8.71s	remaining: 3.32s
# 724:	learn: 360.7541251	total: 8.72s	remaining: 3.31s
# 725:	learn: 360.6617160	total: 8.73s	remaining: 3.3s
# 726:	learn: 360.5678519	total: 8.75s	remaining: 3.28s
# 727:	learn: 360.4863054	total: 8.76s	remaining: 3.27s
# 728:	learn: 360.3120752	total: 8.77s	remaining: 3.26s
# 729:	learn: 360.1541764	total: 8.78s	remaining: 3.25s
# 730:	learn: 359.8926736	total: 8.8s	remaining: 3.24s
# 731:	learn: 359.6790991	total: 8.81s	remaining: 3.23s
# 732:	learn: 359.5606102	total: 8.82s	remaining: 3.21s
# 733:	learn: 359.4797434	total: 8.84s	remaining: 3.2s
# 734:	learn: 359.3581725	total: 8.85s	remaining: 3.19s
# 735:	learn: 359.2020822	total: 8.86s	remaining: 3.18s
# 736:	learn: 359.0611483	total: 8.88s	remaining: 3.17s
# 737:	learn: 358.9513759	total: 8.89s	remaining: 3.16s
# 738:	learn: 358.8887532	total: 8.91s	remaining: 3.15s
# 739:	learn: 358.7709856	total: 8.92s	remaining: 3.13s
# 740:	learn: 358.6204558	total: 8.93s	remaining: 3.12s
# 741:	learn: 358.4383801	total: 8.95s	remaining: 3.11s
# 742:	learn: 358.3504759	total: 8.96s	remaining: 3.1s
# 743:	learn: 358.2294522	total: 8.97s	remaining: 3.09s
# 744:	learn: 358.1090359	total: 8.98s	remaining: 3.07s
# 745:	learn: 357.9448897	total: 9s	remaining: 3.06s
# 746:	learn: 357.7997234	total: 9.01s	remaining: 3.05s
# 747:	learn: 357.6351144	total: 9.02s	remaining: 3.04s
# 748:	learn: 357.5582430	total: 9.04s	remaining: 3.03s
# 749:	learn: 357.4582835	total: 9.05s	remaining: 3.02s
# 750:	learn: 357.2479314	total: 9.06s	remaining: 3s
# 751:	learn: 357.1080383	total: 9.07s	remaining: 2.99s
# 752:	learn: 356.9741961	total: 9.09s	remaining: 2.98s
# 753:	learn: 356.8780558	total: 9.1s	remaining: 2.97s
# 754:	learn: 356.7165776	total: 9.11s	remaining: 2.96s
# 755:	learn: 356.5846625	total: 9.13s	remaining: 2.94s
# 756:	learn: 356.4380679	total: 9.14s	remaining: 2.93s
# 757:	learn: 356.2443904	total: 9.15s	remaining: 2.92s
# 758:	learn: 356.0979802	total: 9.16s	remaining: 2.91s
# 759:	learn: 355.9986711	total: 9.18s	remaining: 2.9s
# 760:	learn: 355.8712409	total: 9.19s	remaining: 2.89s
# 761:	learn: 355.7323996	total: 9.2s	remaining: 2.87s
# 762:	learn: 355.6096720	total: 9.22s	remaining: 2.86s
# 763:	learn: 355.4618745	total: 9.23s	remaining: 2.85s
# 764:	learn: 355.2796136	total: 9.24s	remaining: 2.84s
# 765:	learn: 355.0769941	total: 9.26s	remaining: 2.83s
# 766:	learn: 354.9732362	total: 9.27s	remaining: 2.81s
# 767:	learn: 354.8649115	total: 9.28s	remaining: 2.8s
# 768:	learn: 354.7525723	total: 9.29s	remaining: 2.79s
# 769:	learn: 354.5894182	total: 9.31s	remaining: 2.78s
# 770:	learn: 354.3115502	total: 9.32s	remaining: 2.77s
# 771:	learn: 354.2046644	total: 9.33s	remaining: 2.76s
# 772:	learn: 353.9920880	total: 9.35s	remaining: 2.74s
# 773:	learn: 353.9116483	total: 9.36s	remaining: 2.73s
# 774:	learn: 353.7472332	total: 9.37s	remaining: 2.72s
# 775:	learn: 353.5912509	total: 9.38s	remaining: 2.71s
# 776:	learn: 353.5003464	total: 9.39s	remaining: 2.69s
# 777:	learn: 353.3383534	total: 9.4s	remaining: 2.68s
# 778:	learn: 353.1627872	total: 9.41s	remaining: 2.67s
# 779:	learn: 353.0153123	total: 9.43s	remaining: 2.66s
# 780:	learn: 352.9484610	total: 9.44s	remaining: 2.65s
# 781:	learn: 352.7721616	total: 9.45s	remaining: 2.63s
# 782:	learn: 352.5810349	total: 9.46s	remaining: 2.62s
# 783:	learn: 352.4547044	total: 9.47s	remaining: 2.61s
# 784:	learn: 352.3280438	total: 9.48s	remaining: 2.6s
# 785:	learn: 352.1383298	total: 9.49s	remaining: 2.58s
# 786:	learn: 351.9975759	total: 9.5s	remaining: 2.57s
# 787:	learn: 351.7945092	total: 9.51s	remaining: 2.56s
# 788:	learn: 351.6955232	total: 9.52s	remaining: 2.54s
# 789:	learn: 351.4472714	total: 9.53s	remaining: 2.53s
# 790:	learn: 351.3468323	total: 9.54s	remaining: 2.52s
# 791:	learn: 351.2666452	total: 9.55s	remaining: 2.51s
# 792:	learn: 351.1644239	total: 9.56s	remaining: 2.5s
# 793:	learn: 351.0277182	total: 9.57s	remaining: 2.48s
# 794:	learn: 350.8631561	total: 9.58s	remaining: 2.47s
# 795:	learn: 350.7531549	total: 9.59s	remaining: 2.46s
# 796:	learn: 350.5963229	total: 9.6s	remaining: 2.44s
# 797:	learn: 350.5147078	total: 9.61s	remaining: 2.43s
# 798:	learn: 350.4008583	total: 9.62s	remaining: 2.42s
# 799:	learn: 350.3027226	total: 9.64s	remaining: 2.41s
# 800:	learn: 350.2285406	total: 9.65s	remaining: 2.4s
# 801:	learn: 350.1192273	total: 9.66s	remaining: 2.38s
# 802:	learn: 349.9617491	total: 9.68s	remaining: 2.37s
# 803:	learn: 349.8898633	total: 9.69s	remaining: 2.36s
# 804:	learn: 349.7975318	total: 9.7s	remaining: 2.35s
# 805:	learn: 349.7263844	total: 9.71s	remaining: 2.34s
# 806:	learn: 349.6536779	total: 9.73s	remaining: 2.33s
# 807:	learn: 349.5634633	total: 9.74s	remaining: 2.31s
# 808:	learn: 349.4678701	total: 9.75s	remaining: 2.3s
# 809:	learn: 349.3446936	total: 9.76s	remaining: 2.29s
# 810:	learn: 349.1618071	total: 9.78s	remaining: 2.28s
# 811:	learn: 349.0160392	total: 9.79s	remaining: 2.27s
# 812:	learn: 348.8638141	total: 9.8s	remaining: 2.25s
# 813:	learn: 348.8229068	total: 9.81s	remaining: 2.24s
# 814:	learn: 348.6977224	total: 9.83s	remaining: 2.23s
# 815:	learn: 348.5465158	total: 9.85s	remaining: 2.22s
# 816:	learn: 348.4822219	total: 9.87s	remaining: 2.21s
# 817:	learn: 348.3045379	total: 9.89s	remaining: 2.2s
# 818:	learn: 348.2412010	total: 9.91s	remaining: 2.19s
# 819:	learn: 348.1194549	total: 9.93s	remaining: 2.18s
# 820:	learn: 347.9941442	total: 9.94s	remaining: 2.17s
# 821:	learn: 347.9183322	total: 9.96s	remaining: 2.15s
# 822:	learn: 347.8310766	total: 9.97s	remaining: 2.14s
# 823:	learn: 347.7039523	total: 9.98s	remaining: 2.13s
# 824:	learn: 347.5957435	total: 9.99s	remaining: 2.12s
# 825:	learn: 347.3744493	total: 10s	remaining: 2.11s
# 826:	learn: 347.2069156	total: 10s	remaining: 2.1s
# 827:	learn: 347.0366772	total: 10s	remaining: 2.08s
# 828:	learn: 346.8729079	total: 10s	remaining: 2.07s
# 829:	learn: 346.6893891	total: 10.1s	remaining: 2.06s
# 830:	learn: 346.5915192	total: 10.1s	remaining: 2.05s
# 831:	learn: 346.5554768	total: 10.1s	remaining: 2.04s
# 832:	learn: 346.3384535	total: 10.1s	remaining: 2.02s
# 833:	learn: 346.2203214	total: 10.1s	remaining: 2.01s
# 834:	learn: 346.1418565	total: 10.1s	remaining: 2s
# 835:	learn: 346.0475405	total: 10.1s	remaining: 1.99s
# 836:	learn: 345.8503908	total: 10.2s	remaining: 1.98s
# 837:	learn: 345.6922358	total: 10.2s	remaining: 1.97s
# 838:	learn: 345.5813935	total: 10.2s	remaining: 1.95s
# 839:	learn: 345.4804511	total: 10.2s	remaining: 1.94s
# 840:	learn: 345.3788950	total: 10.2s	remaining: 1.93s
# 841:	learn: 345.3380553	total: 10.2s	remaining: 1.92s
# 842:	learn: 345.3082807	total: 10.2s	remaining: 1.9s
# 843:	learn: 345.1803099	total: 10.2s	remaining: 1.89s
# 844:	learn: 345.0846611	total: 10.3s	remaining: 1.88s
# 845:	learn: 344.8759174	total: 10.3s	remaining: 1.87s
# 846:	learn: 344.6647385	total: 10.3s	remaining: 1.86s
# 847:	learn: 344.5201215	total: 10.3s	remaining: 1.84s
# 848:	learn: 344.3795525	total: 10.3s	remaining: 1.83s
# 849:	learn: 344.3154620	total: 10.3s	remaining: 1.82s
# 850:	learn: 344.2154781	total: 10.3s	remaining: 1.81s
# 851:	learn: 344.0993297	total: 10.3s	remaining: 1.8s
# 852:	learn: 344.0259603	total: 10.4s	remaining: 1.78s
# 853:	learn: 343.9091528	total: 10.4s	remaining: 1.77s
# 854:	learn: 343.7332502	total: 10.4s	remaining: 1.76s
# 855:	learn: 343.5668024	total: 10.4s	remaining: 1.75s
# 856:	learn: 343.4715904	total: 10.4s	remaining: 1.74s
# 857:	learn: 343.2542096	total: 10.4s	remaining: 1.72s
# 858:	learn: 343.1223933	total: 10.4s	remaining: 1.71s
# 859:	learn: 343.0201932	total: 10.4s	remaining: 1.7s
# 860:	learn: 342.9831317	total: 10.5s	remaining: 1.69s
# 861:	learn: 342.9063770	total: 10.5s	remaining: 1.68s
# 862:	learn: 342.7641343	total: 10.5s	remaining: 1.66s
# 863:	learn: 342.5641256	total: 10.5s	remaining: 1.65s
# 864:	learn: 342.4576193	total: 10.5s	remaining: 1.64s
# 865:	learn: 342.3978013	total: 10.5s	remaining: 1.63s
# 866:	learn: 342.3132449	total: 10.5s	remaining: 1.62s
# 867:	learn: 342.0776567	total: 10.6s	remaining: 1.6s
# 868:	learn: 341.9175407	total: 10.6s	remaining: 1.59s
# 869:	learn: 341.8310650	total: 10.6s	remaining: 1.58s
# 870:	learn: 341.7074282	total: 10.6s	remaining: 1.57s
# 871:	learn: 341.6248449	total: 10.6s	remaining: 1.56s
# 872:	learn: 341.4648996	total: 10.6s	remaining: 1.54s
# 873:	learn: 341.3253978	total: 10.6s	remaining: 1.53s
# 874:	learn: 341.2345345	total: 10.6s	remaining: 1.52s
# 875:	learn: 341.1544027	total: 10.7s	remaining: 1.51s
# 876:	learn: 341.0257258	total: 10.7s	remaining: 1.5s
# 877:	learn: 340.8130923	total: 10.7s	remaining: 1.48s
# 878:	learn: 340.6788962	total: 10.7s	remaining: 1.47s
# 879:	learn: 340.6023975	total: 10.7s	remaining: 1.46s
# 880:	learn: 340.4212271	total: 10.7s	remaining: 1.45s
# 881:	learn: 340.2998148	total: 10.7s	remaining: 1.44s
# 882:	learn: 340.1324710	total: 10.7s	remaining: 1.42s
# 883:	learn: 340.0352530	total: 10.8s	remaining: 1.41s
# 884:	learn: 339.8649193	total: 10.8s	remaining: 1.4s
# 885:	learn: 339.7646265	total: 10.8s	remaining: 1.39s
# 886:	learn: 339.6358473	total: 10.8s	remaining: 1.38s
# 887:	learn: 339.5434005	total: 10.8s	remaining: 1.36s
# 888:	learn: 339.4644754	total: 10.8s	remaining: 1.35s
# 889:	learn: 339.3345860	total: 10.8s	remaining: 1.34s
# 890:	learn: 339.1490120	total: 10.8s	remaining: 1.33s
# 891:	learn: 339.0555944	total: 10.9s	remaining: 1.31s
# 892:	learn: 338.9307638	total: 10.9s	remaining: 1.3s
# 893:	learn: 338.8294823	total: 10.9s	remaining: 1.29s
# ...
# 698:	learn: 51.6574513	total: 7.65s	remaining: 3.29s
# 699:	learn: 51.6332623	total: 7.66s	remaining: 3.28s
# 700:	learn: 51.6140370	total: 7.68s	remaining: 3.27s
# 701:	learn: 51.5963649	total: 7.69s	remaining: 3.27s
# 702:	learn: 51.5759859	total: 7.7s	remaining: 3.25s
# 703:	learn: 51.5309366	total: 7.73s	remaining: 3.25s
# 704:	learn: 51.5098065	total: 7.75s	remaining: 3.24s
# 705:	learn: 51.4848799	total: 7.76s	remaining: 3.23s
# 706:	learn: 51.4564842	total: 7.78s	remaining: 3.22s
# 707:	learn: 51.4370671	total: 7.79s	remaining: 3.21s
# 708:	learn: 51.4259345	total: 7.81s	remaining: 3.2s
# 709:	learn: 51.4148409	total: 7.82s	remaining: 3.19s
# 710:	learn: 51.3902739	total: 7.83s	remaining: 3.19s
# 711:	learn: 51.3770899	total: 7.85s	remaining: 3.17s
# 712:	learn: 51.3569753	total: 7.86s	remaining: 3.16s
# 713:	learn: 51.3315376	total: 7.88s	remaining: 3.15s
# 714:	learn: 51.2980955	total: 7.89s	remaining: 3.15s
# 715:	learn: 51.2768136	total: 7.9s	remaining: 3.13s
# 716:	learn: 51.2497777	total: 7.92s	remaining: 3.12s
# 717:	learn: 51.2176396	total: 7.93s	remaining: 3.11s
# 718:	learn: 51.1979145	total: 7.94s	remaining: 3.1s
# 719:	learn: 51.1850516	total: 7.95s	remaining: 3.09s
# 720:	learn: 51.1556236	total: 7.96s	remaining: 3.08s
# 721:	learn: 51.1355871	total: 7.98s	remaining: 3.07s
# 722:	learn: 51.1038143	total: 7.99s	remaining: 3.06s
# 723:	learn: 51.0717562	total: 8.01s	remaining: 3.05s
# 724:	learn: 51.0628021	total: 8.02s	remaining: 3.04s
# 725:	learn: 51.0451738	total: 8.03s	remaining: 3.03s
# 726:	learn: 51.0227486	total: 8.04s	remaining: 3.02s
# 727:	learn: 51.0068240	total: 8.05s	remaining: 3.01s
# 728:	learn: 50.9883212	total: 8.06s	remaining: 3s
# 729:	learn: 50.9607251	total: 8.08s	remaining: 2.99s
# 730:	learn: 50.9371794	total: 8.09s	remaining: 2.98s
# 731:	learn: 50.9118116	total: 8.1s	remaining: 2.97s
# 732:	learn: 50.8833407	total: 8.11s	remaining: 2.96s
# 733:	learn: 50.8659064	total: 8.13s	remaining: 2.94s
# 734:	learn: 50.8402166	total: 8.14s	remaining: 2.93s
# 735:	learn: 50.8116903	total: 8.15s	remaining: 2.92s
# 736:	learn: 50.7796230	total: 8.16s	remaining: 2.91s
# 737:	learn: 50.7582228	total: 8.17s	remaining: 2.9s
# 738:	learn: 50.7464144	total: 8.18s	remaining: 2.89s
# 739:	learn: 50.7053674	total: 8.19s	remaining: 2.88s
# 740:	learn: 50.6793599	total: 8.2s	remaining: 2.87s
# 741:	learn: 50.6573860	total: 8.21s	remaining: 2.85s
# 742:	learn: 50.6211468	total: 8.22s	remaining: 2.84s
# 743:	learn: 50.5870056	total: 8.23s	remaining: 2.83s
# 744:	learn: 50.5758234	total: 8.24s	remaining: 2.82s
# 745:	learn: 50.5629554	total: 8.25s	remaining: 2.81s
# 746:	learn: 50.5426080	total: 8.26s	remaining: 2.8s
# 747:	learn: 50.5121608	total: 8.27s	remaining: 2.79s
# 748:	learn: 50.4857463	total: 8.28s	remaining: 2.77s
# 749:	learn: 50.4662726	total: 8.29s	remaining: 2.76s
# 750:	learn: 50.4370684	total: 8.29s	remaining: 2.75s
# 751:	learn: 50.4122315	total: 8.31s	remaining: 2.74s
# 752:	learn: 50.3959570	total: 8.32s	remaining: 2.73s
# 753:	learn: 50.3736108	total: 8.33s	remaining: 2.72s
# 754:	learn: 50.3555867	total: 8.34s	remaining: 2.71s
# 755:	learn: 50.3337259	total: 8.35s	remaining: 2.69s
# 756:	learn: 50.3112233	total: 8.36s	remaining: 2.68s
# 757:	learn: 50.2825854	total: 8.37s	remaining: 2.67s
# 758:	learn: 50.2611420	total: 8.38s	remaining: 2.66s
# 759:	learn: 50.2322002	total: 8.39s	remaining: 2.65s
# 760:	learn: 50.1997526	total: 8.4s	remaining: 2.64s
# 761:	learn: 50.1646852	total: 8.41s	remaining: 2.63s
# 762:	learn: 50.1379511	total: 8.42s	remaining: 2.62s
# 763:	learn: 50.1172780	total: 8.43s	remaining: 2.6s
# 764:	learn: 50.1040144	total: 8.44s	remaining: 2.59s
# 765:	learn: 50.0775413	total: 8.45s	remaining: 2.58s
# 766:	learn: 50.0696382	total: 8.46s	remaining: 2.57s
# 767:	learn: 50.0467020	total: 8.46s	remaining: 2.56s
# 768:	learn: 50.0272192	total: 8.47s	remaining: 2.54s
# 769:	learn: 50.0077331	total: 8.48s	remaining: 2.53s
# 770:	learn: 49.9883519	total: 8.49s	remaining: 2.52s
# 771:	learn: 49.9652613	total: 8.5s	remaining: 2.51s
# 772:	learn: 49.9450351	total: 8.51s	remaining: 2.5s
# 773:	learn: 49.9278496	total: 8.52s	remaining: 2.49s
# 774:	learn: 49.9075095	total: 8.53s	remaining: 2.48s
# 775:	learn: 49.8876298	total: 8.54s	remaining: 2.46s
# 776:	learn: 49.8701967	total: 8.55s	remaining: 2.45s
# 777:	learn: 49.8477830	total: 8.56s	remaining: 2.44s
# 778:	learn: 49.8229762	total: 8.57s	remaining: 2.43s
# 779:	learn: 49.7901903	total: 8.58s	remaining: 2.42s
# 780:	learn: 49.7652518	total: 8.59s	remaining: 2.41s
# 781:	learn: 49.7503763	total: 8.6s	remaining: 2.4s
# 782:	learn: 49.7187577	total: 8.61s	remaining: 2.38s
# 783:	learn: 49.6826958	total: 8.62s	remaining: 2.37s
# 784:	learn: 49.6651934	total: 8.63s	remaining: 2.36s
# 785:	learn: 49.6443922	total: 8.64s	remaining: 2.35s
# 786:	learn: 49.6226649	total: 8.65s	remaining: 2.34s
# 787:	learn: 49.5994144	total: 8.66s	remaining: 2.33s
# 788:	learn: 49.5777957	total: 8.67s	remaining: 2.32s
# 789:	learn: 49.5480350	total: 8.68s	remaining: 2.31s
# 790:	learn: 49.5244256	total: 8.69s	remaining: 2.29s
# 791:	learn: 49.5082689	total: 8.7s	remaining: 2.28s
# 792:	learn: 49.4863352	total: 8.7s	remaining: 2.27s
# 793:	learn: 49.4610058	total: 8.71s	remaining: 2.26s
# 794:	learn: 49.4375600	total: 8.72s	remaining: 2.25s
# 795:	learn: 49.4178048	total: 8.73s	remaining: 2.24s
# 796:	learn: 49.3956120	total: 8.74s	remaining: 2.23s
# 797:	learn: 49.3597049	total: 8.76s	remaining: 2.22s
# 798:	learn: 49.3450042	total: 8.77s	remaining: 2.21s
# 799:	learn: 49.3263199	total: 8.77s	remaining: 2.19s
# 800:	learn: 49.3068068	total: 8.78s	remaining: 2.18s
# 801:	learn: 49.2868180	total: 8.79s	remaining: 2.17s
# 802:	learn: 49.2585022	total: 8.8s	remaining: 2.16s
# 803:	learn: 49.2296048	total: 8.81s	remaining: 2.15s
# 804:	learn: 49.2038032	total: 8.82s	remaining: 2.14s
# 805:	learn: 49.1841039	total: 8.83s	remaining: 2.13s
# 806:	learn: 49.1499113	total: 8.84s	remaining: 2.11s
# 807:	learn: 49.1336533	total: 8.85s	remaining: 2.1s
# 808:	learn: 49.1212561	total: 8.86s	remaining: 2.09s
# 809:	learn: 49.1037255	total: 8.87s	remaining: 2.08s
# 810:	learn: 49.0931970	total: 8.88s	remaining: 2.07s
# 811:	learn: 49.0637968	total: 8.89s	remaining: 2.06s
# 812:	learn: 49.0510805	total: 8.9s	remaining: 2.05s
# 813:	learn: 49.0252401	total: 8.9s	remaining: 2.03s
# 814:	learn: 49.0049449	total: 8.91s	remaining: 2.02s
# 815:	learn: 48.9893162	total: 8.92s	remaining: 2.01s
# 816:	learn: 48.9621753	total: 8.93s	remaining: 2s
# 817:	learn: 48.9377516	total: 8.94s	remaining: 1.99s
# 818:	learn: 48.9170896	total: 8.95s	remaining: 1.98s
# 819:	learn: 48.8926078	total: 8.96s	remaining: 1.97s
# 820:	learn: 48.8789068	total: 8.98s	remaining: 1.96s
# 821:	learn: 48.8718675	total: 8.99s	remaining: 1.95s
# 822:	learn: 48.8515012	total: 9s	remaining: 1.94s
# 823:	learn: 48.8360309	total: 9.01s	remaining: 1.92s
# 824:	learn: 48.8031627	total: 9.02s	remaining: 1.91s
# 825:	learn: 48.7763667	total: 9.03s	remaining: 1.9s
# 826:	learn: 48.7587114	total: 9.04s	remaining: 1.89s
# 827:	learn: 48.7420262	total: 9.05s	remaining: 1.88s
# 828:	learn: 48.7250157	total: 9.06s	remaining: 1.87s
# 829:	learn: 48.6968219	total: 9.07s	remaining: 1.86s
# 830:	learn: 48.6768215	total: 9.09s	remaining: 1.85s
# 831:	learn: 48.6433047	total: 9.1s	remaining: 1.84s
# 832:	learn: 48.6015133	total: 9.11s	remaining: 1.83s
# 833:	learn: 48.5761442	total: 9.12s	remaining: 1.81s
# 834:	learn: 48.5664194	total: 9.13s	remaining: 1.8s
# 835:	learn: 48.5541788	total: 9.14s	remaining: 1.79s
# 836:	learn: 48.5249024	total: 9.15s	remaining: 1.78s
# 837:	learn: 48.5033935	total: 9.16s	remaining: 1.77s
# 838:	learn: 48.4885299	total: 9.17s	remaining: 1.76s
# 839:	learn: 48.4743550	total: 9.19s	remaining: 1.75s
# 840:	learn: 48.4422409	total: 9.2s	remaining: 1.74s
# 841:	learn: 48.4223362	total: 9.21s	remaining: 1.73s
# 842:	learn: 48.3962296	total: 9.22s	remaining: 1.72s
# 843:	learn: 48.3676499	total: 9.23s	remaining: 1.71s
# 844:	learn: 48.3590478	total: 9.24s	remaining: 1.7s
# 845:	learn: 48.3320498	total: 9.25s	remaining: 1.68s
# 846:	learn: 48.3119870	total: 9.26s	remaining: 1.67s
# 847:	learn: 48.2934106	total: 9.27s	remaining: 1.66s
# 848:	learn: 48.2758655	total: 9.29s	remaining: 1.65s
# 849:	learn: 48.2626223	total: 9.29s	remaining: 1.64s
# 850:	learn: 48.2447168	total: 9.31s	remaining: 1.63s
# 851:	learn: 48.2087456	total: 9.32s	remaining: 1.62s
# 852:	learn: 48.1826635	total: 9.33s	remaining: 1.61s
# 853:	learn: 48.1735356	total: 9.34s	remaining: 1.6s
# 854:	learn: 48.1719146	total: 9.35s	remaining: 1.58s
# 855:	learn: 48.1559092	total: 9.35s	remaining: 1.57s
# 856:	learn: 48.1398353	total: 9.36s	remaining: 1.56s
# 857:	learn: 48.1090506	total: 9.37s	remaining: 1.55s
# 858:	learn: 48.0886509	total: 9.38s	remaining: 1.54s
# 859:	learn: 48.0698015	total: 9.39s	remaining: 1.53s
# 860:	learn: 48.0523175	total: 9.4s	remaining: 1.52s
# 861:	learn: 48.0352878	total: 9.41s	remaining: 1.51s
# 862:	learn: 48.0184150	total: 9.42s	remaining: 1.5s
# 863:	learn: 48.0101193	total: 9.43s	remaining: 1.48s
# 864:	learn: 47.9866712	total: 9.44s	remaining: 1.47s
# 865:	learn: 47.9690617	total: 9.45s	remaining: 1.46s
# 866:	learn: 47.9403255	total: 9.46s	remaining: 1.45s
# 867:	learn: 47.9292720	total: 9.47s	remaining: 1.44s
# 868:	learn: 47.9120778	total: 9.48s	remaining: 1.43s
# 869:	learn: 47.8850340	total: 9.49s	remaining: 1.42s
# 870:	learn: 47.8685123	total: 9.5s	remaining: 1.41s
# 871:	learn: 47.8465942	total: 9.51s	remaining: 1.4s
# 872:	learn: 47.8323354	total: 9.52s	remaining: 1.38s
# 873:	learn: 47.8175033	total: 9.53s	remaining: 1.37s
# 874:	learn: 47.7998626	total: 9.54s	remaining: 1.36s
# 875:	learn: 47.7841198	total: 9.55s	remaining: 1.35s
# 876:	learn: 47.7606488	total: 9.56s	remaining: 1.34s
# 877:	learn: 47.7467361	total: 9.57s	remaining: 1.33s
# 878:	learn: 47.7354377	total: 9.58s	remaining: 1.32s
# 879:	learn: 47.7123122	total: 9.59s	remaining: 1.31s
# 880:	learn: 47.6924349	total: 9.6s	remaining: 1.3s
# 881:	learn: 47.6763518	total: 9.61s	remaining: 1.28s
# 882:	learn: 47.6601601	total: 9.61s	remaining: 1.27s
# 883:	learn: 47.6449098	total: 9.62s	remaining: 1.26s
# 884:	learn: 47.6350152	total: 9.63s	remaining: 1.25s
# 885:	learn: 47.6043584	total: 9.64s	remaining: 1.24s
# 886:	learn: 47.5875327	total: 9.65s	remaining: 1.23s
# 887:	learn: 47.5603745	total: 9.66s	remaining: 1.22s
# 888:	learn: 47.5505032	total: 9.67s	remaining: 1.21s
# 889:	learn: 47.5184585	total: 9.68s	remaining: 1.2s
# 890:	learn: 47.4867627	total: 9.69s	remaining: 1.19s
# 891:	learn: 47.4726544	total: 9.7s	remaining: 1.17s
# 892:	learn: 47.4513645	total: 9.71s	remaining: 1.16s
# 893:	learn: 47.4298835	total: 9.72s	remaining: 1.15s
# 894:	learn: 47.4039735	total: 9.73s	remaining: 1.14s
# 895:	learn: 47.3747193	total: 9.74s	remaining: 1.13s
# 896:	learn: 47.3634278	total: 9.75s	remaining: 1.12s
# 897:	learn: 47.3335933	total: 9.76s	remaining: 1.11s
# 898:	learn: 47.3000306	total: 9.77s	remaining: 1.1s
# 899:	learn: 47.2948124	total: 9.78s	remaining: 1.09s
# 900:	learn: 47.2846558	total: 9.79s	remaining: 1.07s
# 901:	learn: 47.2624370	total: 9.8s	remaining: 1.06s
# 902:	learn: 47.2341676	total: 9.81s	remaining: 1.05s
# 903:	learn: 47.2098240	total: 9.82s	remaining: 1.04s
# 904:	learn: 47.1943631	total: 9.83s	remaining: 1.03s
# 905:	learn: 47.1726409	total: 9.84s	remaining: 1.02s
# 906:	learn: 47.1546502	total: 9.85s	remaining: 1.01s
# 907:	learn: 47.1400924	total: 9.86s	remaining: 999ms
# 908:	learn: 47.1263423	total: 9.86s	remaining: 988ms
# 909:	learn: 47.1105868	total: 9.87s	remaining: 977ms
# 910:	learn: 47.0927765	total: 9.88s	remaining: 966ms
# 911:	learn: 47.0659860	total: 9.89s	remaining: 955ms
# 912:	learn: 47.0366479	total: 9.9s	remaining: 944ms
# 913:	learn: 47.0227538	total: 9.91s	remaining: 933ms
# 914:	learn: 47.0063021	total: 9.93s	remaining: 923ms
# 915:	learn: 47.0025792	total: 9.95s	remaining: 912ms
# 916:	learn: 46.9610356	total: 9.96s	remaining: 901ms
# 917:	learn: 46.9354422	total: 9.97s	remaining: 891ms
# 918:	learn: 46.9159298	total: 9.98s	remaining: 880ms
# 919:	learn: 46.8917526	total: 9.99s	remaining: 869ms
# 920:	learn: 46.8700755	total: 10s	remaining: 858ms
# 921:	learn: 46.8567135	total: 10s	remaining: 847ms
# 922:	learn: 46.8366216	total: 10s	remaining: 836ms
# 923:	learn: 46.8238811	total: 10s	remaining: 825ms
# 924:	learn: 46.7974601	total: 10s	remaining: 814ms
# 925:	learn: 46.7878136	total: 10s	remaining: 803ms
# 926:	learn: 46.7760508	total: 10.1s	remaining: 792ms
# 927:	learn: 46.7550099	total: 10.1s	remaining: 781ms
# 928:	learn: 46.7402111	total: 10.1s	remaining: 770ms
# 929:	learn: 46.7177672	total: 10.1s	remaining: 759ms
# 930:	learn: 46.6845532	total: 10.1s	remaining: 748ms
# 931:	learn: 46.6763014	total: 10.1s	remaining: 737ms
# 932:	learn: 46.6588261	total: 10.1s	remaining: 726ms
# 933:	learn: 46.6519566	total: 10.1s	remaining: 715ms
# 934:	learn: 46.6286317	total: 10.1s	remaining: 705ms
# 935:	learn: 46.6031807	total: 10.1s	remaining: 694ms
# 936:	learn: 46.5889729	total: 10.2s	remaining: 683ms
# 937:	learn: 46.5713180	total: 10.2s	remaining: 672ms
# 938:	learn: 46.5459649	total: 10.2s	remaining: 661ms
# 939:	learn: 46.5282106	total: 10.2s	remaining: 650ms
# 940:	learn: 46.5081681	total: 10.2s	remaining: 639ms
# 941:	learn: 46.4915658	total: 10.2s	remaining: 628ms
# 942:	learn: 46.4824046	total: 10.2s	remaining: 617ms
# 943:	learn: 46.4754659	total: 10.2s	remaining: 606ms
# 944:	learn: 46.4624724	total: 10.2s	remaining: 595ms
# 945:	learn: 46.4499816	total: 10.2s	remaining: 585ms
# 946:	learn: 46.4300132	total: 10.3s	remaining: 574ms
# 947:	learn: 46.4156086	total: 10.3s	remaining: 563ms
# 948:	learn: 46.4068061	total: 10.3s	remaining: 552ms
# 949:	learn: 46.4002552	total: 10.3s	remaining: 541ms
# 950:	learn: 46.3763346	total: 10.3s	remaining: 530ms
# 951:	learn: 46.3681372	total: 10.3s	remaining: 520ms
# 952:	learn: 46.3528356	total: 10.3s	remaining: 509ms
# 953:	learn: 46.3343035	total: 10.3s	remaining: 498ms
# 954:	learn: 46.3178936	total: 10.3s	remaining: 487ms
# 955:	learn: 46.2951286	total: 10.3s	remaining: 476ms
# 956:	learn: 46.2825083	total: 10.4s	remaining: 465ms
# 957:	learn: 46.2502831	total: 10.4s	remaining: 455ms
# 958:	learn: 46.2385645	total: 10.4s	remaining: 444ms
# 959:	learn: 46.2136761	total: 10.4s	remaining: 433ms
# 960:	learn: 46.1904005	total: 10.4s	remaining: 422ms
# 961:	learn: 46.1653015	total: 10.4s	remaining: 411ms
# 962:	learn: 46.1504645	total: 10.4s	remaining: 401ms
# 963:	learn: 46.1364296	total: 10.4s	remaining: 390ms
# 964:	learn: 46.1144045	total: 10.5s	remaining: 379ms
# 965:	learn: 46.0974957	total: 10.5s	remaining: 368ms
# 966:	learn: 46.0834776	total: 10.5s	remaining: 358ms
# 967:	learn: 46.0685860	total: 10.5s	remaining: 347ms
# 968:	learn: 46.0546325	total: 10.5s	remaining: 336ms
# 969:	learn: 46.0358623	total: 10.5s	remaining: 325ms
# 970:	learn: 45.9987860	total: 10.5s	remaining: 315ms
# 971:	learn: 45.9811031	total: 10.5s	remaining: 304ms
# 972:	learn: 45.9537988	total: 10.6s	remaining: 293ms
# 973:	learn: 45.9339894	total: 10.6s	remaining: 282ms
# 974:	learn: 45.9077074	total: 10.6s	remaining: 271ms
# 975:	learn: 45.8825476	total: 10.6s	remaining: 261ms
# 976:	learn: 45.8578834	total: 10.6s	remaining: 250ms
# 977:	learn: 45.8472389	total: 10.6s	remaining: 239ms
# 978:	learn: 45.8270150	total: 10.6s	remaining: 228ms
# 979:	learn: 45.8070321	total: 10.6s	remaining: 217ms
# 980:	learn: 45.7866547	total: 10.7s	remaining: 206ms
# 981:	learn: 45.7670583	total: 10.7s	remaining: 196ms
# 982:	learn: 45.7458378	total: 10.7s	remaining: 185ms
# 983:	learn: 45.7252213	total: 10.7s	remaining: 174ms
# 984:	learn: 45.7000885	total: 10.7s	remaining: 163ms
# 985:	learn: 45.6798876	total: 10.7s	remaining: 152ms
# 986:	learn: 45.6602196	total: 10.7s	remaining: 141ms
# 987:	learn: 45.6368211	total: 10.7s	remaining: 130ms
# 988:	learn: 45.6085776	total: 10.7s	remaining: 120ms
# 989:	learn: 45.5990145	total: 10.8s	remaining: 109ms
# 990:	learn: 45.5710602	total: 10.8s	remaining: 97.8ms
# 991:	learn: 45.5523261	total: 10.8s	remaining: 87ms
# 992:	learn: 45.5323528	total: 10.8s	remaining: 76.1ms
# 993:	learn: 45.5089154	total: 10.8s	remaining: 65.2ms
# 994:	learn: 45.4917812	total: 10.8s	remaining: 54.4ms
# 995:	learn: 45.4787405	total: 10.8s	remaining: 43.5ms
# 996:	learn: 45.4696847	total: 10.8s	remaining: 32.6ms
# 997:	learn: 45.4558373	total: 10.9s	remaining: 21.8ms
# 998:	learn: 45.4432088	total: 10.9s	remaining: 10.9ms
# 999:	learn: 45.4307648	total: 10.9s	remaining: 0us

# %%
# PREDS

pred_A = catModel_a.predict(X_A_test)
pred_B = catModel_b.predict(X_B_test)
pred_C = catModel_c.predict(X_C_test)

# %%
# GENERATING SUBMISSION FILE

df_A = pd.DataFrame()

df_A["predict"] = pred_A
df_A["location"] = "A"

df_B = pd.DataFrame()

df_B["predict"] = pred_B
df_B["location"] = "B"

df_C = pd.DataFrame()

df_C["predict"] = pred_C
df_C["location"] = "C"

df_mid = pd.concat([df_A, df_B], ignore_index=True)

df = pd.concat([df_mid, df_C], join="inner", ignore_index=True)

df = df.drop("location", axis=1)

df[df<0] = 0

df.shape
# Out:
# (2160, 1)

# %% [markdown]
# # Save

# %%
name = 'short_nb_sub_1'
df.to_csv("./"+ name +".csv")
