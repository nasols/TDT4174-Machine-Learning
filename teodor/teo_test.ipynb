# %%
import pandas as pd

df = pd.read_csv("dnn_kaggle3/optuna_sub_0.csv")
df
# Out:
#         id  prediction
# 0        0    0.000000
# 1        1    0.000000
# 2        2    0.000000
# 3        3    3.566325
# 4        4  402.589320
# ...    ...         ...
# 2155  2155   19.993550
# 2156  2156    0.000000
# 2157  2157    0.000000
# 2158  2158    0.000000
# 2159  2159    0.000000
#
# [2160 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.plot(df['prediction'])
